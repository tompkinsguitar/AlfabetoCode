# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from alfabeto_code import chronology as ch
from alfabeto_code import AlfabetoGraphs as gra

# %%
ch.kaps_plotter_2(ch.kap1, 'all', 2, 10, 'All', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap2, 'all', 2, 10, 'All', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap3, 'all', 2, 10, 'All', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap4, 'all', 2, 10, 'All', 'all', 'guitar')

# %%
ch.kaps_plotter_2(ch.kap1, 'all', 4, 10, 'All', 'first', 'guitar')
ch.kaps_plotter_2(ch.kap2, 'all', 4, 10, 'All', 'first', 'guitar')
ch.kaps_plotter_2(ch.kap3, 'all', 4, 10, 'All', 'first', 'guitar')
ch.kaps_plotter_2(ch.kap4, 'all', 4, 10, 'All', 'first', 'guitar')

# %%
ch.kaps_plotter_2(ch.kap1, 'all', 4, 10, 'Upbeats', 'last', 'guitar')
ch.kaps_plotter_2(ch.kap1, 'all', 4, 10, 'Upbeats', 'last', 'guitar')

# %%
ch.kaps_plotter_2(ch.kap1, 'all', 5, 10, 'All', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap1, 'all', 5, 10, 'Downbeats', 'first', 'guitar')
ch.kaps_plotter_2(ch.kap1, 'all', 5, 10, 'Upbeats', 'last', 'guitar')
ch.kaps_plotter_2(ch.kap1, 'all', 5, 10, 'Up and Downbeats', 'first_and_last', 'guitar')

# %%
for x in something:
    if x == x+1:
        print('yes')

# %%
new_something

# %%
something

# %%
from music21 import *

# %%
G = note.Note('G')

# %%
G
# Out:
# <music21.note.Note G>

# %%
G = chord.Chord([7, 11, 2])

# %%
G
# Out:
# <music21.chord.Chord G B D>

# %%
G.root()
# Out:
# <music21.pitch.Pitch G>

# %%
G.root().pitchClass
# Out:
# 7
