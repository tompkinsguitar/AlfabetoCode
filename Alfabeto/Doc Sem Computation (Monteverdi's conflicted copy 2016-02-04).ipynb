# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# This imports some python modules I made

# %%
from alfabeto_code import chronology as ch
from alfabeto_code import AlfabetoGraphs as gra
from alfabeto_sources import *

# %% [markdown]
# Here are bigram graphs of chords that go to I:

# %%
gra.make_ngram_graph_2(gra.kap1, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap2, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap3, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap4, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap5, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap6, 'major', 3, 'V', 'all', 'guitar')
gra.make_ngram_graph_2(gra.kap7, 'major', 3, 'V', 'all', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (15, 10)

# %%
ch.kaps_plotter(2, 'major', 20, "Bigrams for Kapsperger Villanella Corpus", 'all', 'guitar')
ch.kaps_plotter(3, 'major', 20, "Trigrams for Kapsperger Villanella Corpus", 'all', 'guitar')
ch.kaps_plotter(4, 'major', 20, "4-grams for Kapsperger Villanella Corpus", 'all', 'guitar')
ch.kaps_plotter(5, 'major', 20, "5-grams for Kapsperger Villanella Corpus", 'all', 'guitar')
# Out:
# {'k1': [0,
#   1.935483870967742,
#   0,
#   0.3225806451612903,
#   0,
#   0,
#   0.6451612903225806,
#   0,
#   0.967741935483871,
#   0.3225806451612903,
#   0.3225806451612903,
#   0.3225806451612903,
#   0,
#   0.3225806451612903,
#   0.6451612903225806,
#   0.967741935483871,
#   0,
#   0,
#   0,
#   0],
#  'k2': [0.24875621890547264,
#   0,
#   0.24875621890547264,
#   0.4975124378109453,
#   1.2437810945273633,
#   0.4975124378109453,
#   0,
#   0.24875621890547264,
#   0.4975124378109453,
#   0.24875621890547264,
#   0.4975124378109453,
#   0.4975124378109453,
#   0.7462686567164178,
#   0.4975124378109453,
#   0,
#   0.24875621890547264,
#   0.7462686567164178,
#   0.24875621890547264,
#   0.24875621890547264,
#   0],
#  'k3': [0.3597122302158274,
#   1.4388489208633095,
#   0,
#   1.079136690647482,
#   0.3597122302158274,
#   0,
#   0.7194244604316548,
#   0,
#   0,
#   0.3597122302158274,
#   0.3597122302158274,
#   0.3597122302158274,
#   0.3597122302158274,
# ...

# %% [markdown]
# The top 50 bigrams

# %%
pylab.rcParams['figure.figsize'] = (10, 5)
ch.kaps_plotter_2(ch.kap1, 'major', 3, 10, 'Top 10 Trigrams in Book 1 (1610)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap2, 'major', 3, 10, 'Top 10 Trigrams in Book 2 (1619)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap3, 'major', 3, 10, 'Top 10 Trigrams in Book 3 (1619)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap4, 'major', 3, 10, 'Top 10 Trigrams in Book 4 (1623)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap5, 'major', 3, 10, 'Top 10 Trigrams in Book 5 (1630)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap6, 'major', 3, 10, 'Top 10 Trigrams in Book 6 (1632)', 'all', 'guitar')
ch.kaps_plotter_2(ch.kap7, 'major', 3, 10, 'Top 10 Trigrams in Book 7 (1640)', 'all', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
gra.make_ngram_graph(gra.kap1, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap5, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap6, 'major', 2, 'all', 'guitar')
gra.make_ngram_graph(gra.kap7, 'major', 2, 'all', 'guitar')
print('book 1 tab')
gra.make_ngram_graph([kapsperger.v1_theorbo], 'major', 2, 'all', 'theorbo')
print('all kapsperger:')
gra.make_ngram_graph(gra.all_kaps, 'major', 2, 'all', 'guitar')
print('sanz')
gra.make_ngram_graph(gra.sanz, 'major', 2, 'all', 'guitar')
print('all alfabeto')
gra.make_ngram_graph(gra.all_alfabeto, 'major', 2, 'all', 'guitar')
# Out:
# book 1 tab
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9c52b9fe1594> in <module>()
#       8 gra.make_ngram_graph(gra.kap7, 'major', 2, 'all', 'guitar')
#       9 print('book 1 tab')
# ---> 10 gra.make_ngram_graph([kapsperger.v1_theorbo], 'major', 2, 'all', 'theorbo')
#      11 print('all kapsperger:')
#      12 gra.make_ngram_graph(gra.all_kaps, 'major', 2, 'all', 'guitar')
#
# AttributeError: module 'alfabeto_sources.kapsperger' has no attribute 'v1_theorbo'

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
gra.make_ngram_graph(gra.kap1, 'major', 2, 'first_and_last', 'guitar')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'first_and_last', 'guitar')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'first_and_last', 'guitar')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'first_and_last', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
gra.make_ngram_graph(gra.kap1, 'major', 2, 'first', 'guitar')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'first', 'guitar')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'first', 'guitar')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'first', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
print('Kapsperger book 1')
gra.make_ngram_graph(gra.kap1, 'major', 2, 'all', 'guitar')
print('Kapsperger book 2')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'all', 'guitar')
print('Kapsperger book 3')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'all', 'guitar')
print('Kapsperger book 4')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'all', 'guitar')
print('Stefani')
gra.make_ngram_graph([gra.all_corpus[-1]], 'major', 2, 'all', 'guitar')
print('Obizzi')
gra.make_ngram_graph([gra.all_corpus[-2]], 'major', 2, 'all', 'guitar')
print('Sanz')
gra.make_ngram_graph(gra.sanz, 'major', 2, 'all', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
print('Kapsperger book 1')
gra.make_ngram_graph(gra.kap1, 'major', 2, 'first', 'guitar')
print('Kapsperger book 2')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'first', 'guitar')
print('Kapsperger book 3')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'first', 'guitar')
print('Kapsperger book 4')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'first', 'guitar')
print('Stefani')
gra.make_ngram_graph([gra.all_corpus[-1]], 'major', 2, 'first', 'guitar')
print('Obizzi')
gra.make_ngram_graph([gra.all_corpus[-2]], 'major', 2, 'first', 'guitar')
print('Sanz')
gra.make_ngram_graph(gra.sanz, 'major', 2, 'first', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
print('Kapsperger book 1')
gra.make_ngram_graph(gra.kap1, 'major', 2, 'last', 'guitar')
print('Kapsperger book 2')
gra.make_ngram_graph(gra.kap2, 'major', 2, 'last', 'guitar')
print('Kapsperger book 3')
gra.make_ngram_graph(gra.kap3, 'major', 2, 'last', 'guitar')
print('Kapsperger book 4')
gra.make_ngram_graph(gra.kap4, 'major', 2, 'last', 'guitar')
print('Stefani')
gra.make_ngram_graph([gra.all_corpus[-1]], 'major', 2, 'last', 'guitar')
print('Obizzi')
gra.make_ngram_graph([gra.all_corpus[-2]], 'major', 2, 'last', 'guitar')
print('Sanz')
gra.make_ngram_graph(gra.sanz, 'major', 2, 'last', 'guitar')

# %%
pylab.rcParams['figure.figsize'] = (9, 8)
print('Kapsperger book 1')
gra.make_ngram_graph(gra.kap1, 'minor', 2, 'first_and_last', 'guitar')
print('Kapsperger book 2')
gra.make_ngram_graph(gra.kap2, 'minor', 2, 'first_and_last', 'guitar')
print('Kapsperger book 3')
gra.make_ngram_graph(gra.kap3, 'minor', 2, 'first_and_last', 'guitar')
print('Kapsperger book 4')
gra.make_ngram_graph(gra.kap4, 'minor', 2, 'first_and_last', 'guitar')
print('Stefani')
gra.make_ngram_graph([gra.all_corpus[-1]], 'minor', 2, 'first_and_last', 'guitar')
print('Obizzi')
gra.make_ngram_graph([gra.all_corpus[-2]], 'minor', 2, 'first_and_last', 'guitar')
print('Sanz')
gra.make_ngram_graph(gra.sanz, 'minor', 2, 'first_and_last', 'guitar')
