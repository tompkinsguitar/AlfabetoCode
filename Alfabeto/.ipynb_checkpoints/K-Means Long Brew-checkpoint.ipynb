# %%
# from time import time
import numpy as np
# import matplotlib.pyplot as plt

# from sklearn import metrics
# from sklearn.cluster import KMeans
# from sklearn.datasets import load_digits
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import scale

from scipy.spatial.distance import euclidean, cityblock
import numpy as np
import networkx as nx
from networkx.drawing.nx_agraph import to_agraph

from music21 import *
from alfabeto_sources.all_sources import *
from alfabeto_code.AlfabetoConverter import AlfabetoDict
from Continuo.kmeans_inversion import k_means_data, silhouette_analysis, label_maker_alf
# from Continuo.kmeans import final_alf_labels
from alfabeto_data.pickled_data import *

# %%
def label_maker(label_tuples):
    final_labels = []
    for x in label_tuples:
        final_labels.append('$'+str(x[0])+':'+str(x[1])+'$')
    return final_labels

def label_maker_alf(corpus_list):
    alf_labels = []
    for x in corpus_list: #do this if the tuples are in list of list
        if x == ('f',2) or x == (-1, 2):
            alf_labels.append('$♭:D$')
        elif x == ('n',4) or x == (0, 4):
            alf_labels.append('$♮:E$')
        elif x == ('n',9) or x == (0, 9):
            alf_labels.append('$♮:A$')
        elif x == ('f',7) or x == (-1, 7):
            alf_labels.append('$♭:G$')
        elif x == ('n',2) or x == (0, 2):
            alf_labels.append('$♮:D$')
        elif x == ('f',9) or x == (-1, 9):
            alf_labels.append('$♭:A$')
        elif x == ('f',0) or x == (-1, 0):
            alf_labels.append('$♭:C$')
        elif x == ('f',10) or x == (-1, 10):
            alf_labels.append('$♭:B♭$')
        elif x == ('n',5) or x == (0, 5):
            alf_labels.append('$♮:F$')
        elif x == ('n',0) or x == (0, 0):
            alf_labels.append('$♮:C$')
        elif x == ('f',5) or x == (-1, 5):
            alf_labels.append('$♭:F$')
        elif x == ('n',7) or x == (0, 7):
            alf_labels.append('$♮:G$')
        else:
            alf_labels.append('o')
    return alf_labels

# %%
def averaged_octave_harmonization(flattened_list_with_labels):
    total_chunks = []
    averaged_chunks = []
    all_keys = []
    final_unchunked = []
    for x in flattened_list_with_labels[1]:
        if x not in all_keys:
            all_keys.append(x)
    for x in all_keys:
        a_key = []
        for a, b in zip(flattened_list_with_labels[0], flattened_list_with_labels[1]):
            if b == x:
                a_key.append(a)
        averaged_chunks.append([sum(col) / len(col) for col in zip(*a_key)])

#     for x in total_chunks:
#         song_temp = []
#         for y in x:
#             for z in y:
#                 song_temp.append(z)
#         final_unchunked.append(song_temp)
    return averaged_chunks, all_keys

# %%
# %matplotlib inline
alf_ave = averaged_octave_harmonization(corelli_notes_data)
k_means_data(alf_ave[0], 2, label_maker(alf_ave[1]))
k_means_data(corelli_notes_data[0], 3, label_maker(corelli_notes_data[1]))
# Out:
# n_digits: 2, 	 n_samples 8, 	 n_features 12
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.06s    342   0.318   1.000   0.483   0.000   -0.000    0.692
#    random   0.04s    342   0.318   1.000   0.483   0.000   -0.000    0.692
# PCA-based   0.01s    924   0.270   1.000   0.426   0.000   -0.000    0.363
# _______________________________________________________________________________
# n_digits: 3, 	 n_samples 120, 	 n_features 12
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.11s    5741   0.435   0.902   0.587   0.360   0.415    0.609
#    random   0.10s    5741   0.435   0.902   0.587   0.360   0.415    0.609
# PCA-based   0.01s    5741   0.435   0.902   0.587   0.360   0.415    0.609
# ...

# %%
for x in range(2, 13):
    k_means_data(corelli_notes_data[0], x, label_maker(corelli_notes_data[1]))
# Out:
# n_digits: 2, 	 n_samples 120, 	 n_features 12
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.07s    9343   0.357   1.000   0.526   0.315   0.346    0.603
#    random   0.06s    9343   0.357   1.000   0.526   0.315   0.346    0.603
# PCA-based   0.01s    9343   0.357   1.000   0.526   0.315   0.346    0.603
# _______________________________________________________________________________
# n_digits: 3, 	 n_samples 120, 	 n_features 12
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.09s    5741   0.435   0.902   0.587   0.360   0.415    0.609
#    random   0.15s    5741   0.435   0.902   0.587   0.360   0.415    0.609
# PCA-based   0.01s    5741   0.435   0.902   0.587   0.360   0.415    0.609
# ...

# %%
print('alfabeto')
alf_labels = []
for x in range(len(alfabeto_notes_data)):
    alf_labels.append('$ALF$')
alfabeto_notes = k_means_data(alfabeto_notes_data, 2, alf_labels)

print('bach')
bach_labels = []
for x in range(len(bach_notes_data)):
    bach_labels.append('$JSB$')
bach_notes = k_means_data(bach_notes_data, 2, bach_labels)

print('beethoven')
beethoven_labels = []
for x in range(len(beethoven_notes_data)):
    beethoven_labels.append('$LVB$')
beethoven_notes = k_means_data(beethoven_notes_data, 2, beethoven_labels)

print('haydn')
haydn_labels = []
for x in range(len(haydn_notes_data)):
    haydn_labels.append('$HDN$')
haydn_notes = k_means_data(haydn_notes_data, 2, haydn_labels)

print('monteverdi')
monteverdi_labels = []
for x in range(len(monteverdi_notes_data)):
    monteverdi_labels.append('$CMV$')
monteverdi_notes = k_means_data(monteverdi_notes_data, 2, monteverdi_labels)

print('mozart')
mozart_labels = []
for x in range(len(mozart_notes_data)):
    mozart_labels.append('$MOZ$')
mozart_notes = k_means_data(mozart_notes_data, 2, mozart_labels)

print('palestrina')
palestrina_labels = []
for x in range(len(palestrina_notes_data)):
    palestrina_labels.append('$PAL$')
palestrina_notes = k_means_data(palestrina_notes_data, 2, palestrina_labels)

print('trecento')
trecento_labels = []
for x in range(len(trecento_notes_data)):
    trecento_labels.append('$TRE$')
trecento_notes = k_means_data(trecento_notes_data, 2, trecento_labels)

# %%
average_alf = []
average_bach = []
average_beethoven = []
average_haydn = []
average_monteverdi = []
average_mozart = []
average_palestrina = []
average_trecento = []

# %%
temp_maj = {0: 0.184, 1: 0.001, 2: 0.155, 3: 0.003, 4: 0.191,
            5: 0.109, 6: 0.005, 7: 0.214, 8: 0.001, 9: 0.078,
            10: 0.004, 11: 0.055}

temp_min = {0: 0.192, 1: 0.005, 2: 0.149, 3: 0.179, 4: 0.002,
            5: 0.144, 6: 0.002, 7: 0.201, 8: 0.038, 9: 0.012,
            10: 0.053, 11: 0.022}

t_maj = [temp_maj[x] * 100 for x in range(12)]
t_min = [temp_min[x] * 100 for x in range(12)]

all_corpus = []
all_labels = []

all_corpus.append([sum(col)/len(col) for col in zip(*alfabeto_notes_data)])
for x in alfabeto_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*bach_notes_data)])
for x in bach_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*beethoven_notes_data)])
for x in beethoven_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*haydn_notes_data)])
for x in haydn_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*monteverdi_notes_data)])
for x in monteverdi_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*mozart_notes_data)])
for x in mozart_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*palestrina_notes_data)])
for x in palestrina_notes_data:
    all_corpus.append(x)

all_corpus.append([sum(col)/len(col) for col in zip(*trecento_notes_data)])
for x in trecento_notes_data:
    all_corpus.append(x)
all_corpus.append(t_maj)
all_corpus.append(t_min)


all_labels.append('$*ALF$')
for x in alf_labels:
    all_labels.append(x)

all_labels.append('$*JSB$')
for x in bach_labels:
    all_labels.append(x)

all_labels.append('$*LVB$')    
for x in beethoven_labels:
    all_labels.append(x)

all_labels.append('$*HAY$')    
for x in haydn_labels:
    all_labels.append(x)

all_labels.append('$*CMV$')    
for x in monteverdi_labels:
    all_labels.append(x)


all_labels.append('$*MOZ$')    
for x in mozart_labels:
    all_labels.append(x)

all_labels.append('$*PAL$')    
for x in palestrina_labels:
    all_labels.append(x)

all_labels.append('$*TRE$')    
for x in trecento_labels:
    all_labels.append(x)
all_labels.append('$Temperley MAJOR$')
all_labels.append('$Temperley MINOR$')

# print(all_corpus)
# all_corpus
# %matplotlib qt
x = k_means_data(all_corpus, 2, all_labels)

# %%
# %matplotlib qt
k_means_data(all_corpus, 2, all_labels)

# %%
# %matplotlib inline
silhouette_analysis(x, 12)

# %%
# print('alfabeto')

# silhouette_data(alfabeto_notes, 8)

# print('bach')
# silhouette_data(bach_notes, 8)

# print('beethoven')
# silhouette_data(beethoven_notes, 8)

# print('haydn')
# silhouette_data(haydn_notes, 8)

# print('monteverdi')
# silhouette_data(monteverdi_notes, 8)

# print('mozart')
# silhouette_data(mozart_notes, 8)

print('palestrina')
silhouette_analysis(palestrina_notes, 8)

print('trecento')
silhouette_analysis(trecento_notes, 8)

# %%
def k_means_data_all(list_of_lists, cluster_number):
    np.random.seed(42)

    digits = np.array(list_of_lists)
    # data = scale(digits)
    data = digits

    label_numbers = []
    for i in range(len(list_of_lists)):
        label_numbers.append(i)

#     n_samples = len(list_of_lists)
#     n_features = 12
    n_samples, n_features = data.shape
    n_digits = cluster_number
    labels = np.array(label_numbers)

    # sample_size = 300

    sample_size = len(data)

    print("n_digits: %d, \t n_samples %d, \t n_features %d"
          % (n_digits, n_samples, n_features))

    print(79 * '_')
    print('% 9s' % 'init'
                   '    time  inertia    homo   compl  v-meas     ARI AMI  silhouette')

    def bench_k_means(estimator, name, data):
        t0 = time()
        estimator.fit(data)
        print('% 9s   %.2fs    %i   %.3f   %.3f   %.3f   %.3f   %.3f    %.3f'
              % (name, (time() - t0), estimator.inertia_,
                 metrics.homogeneity_score(labels, estimator.labels_),
                 metrics.completeness_score(labels, estimator.labels_),
                 metrics.v_measure_score(labels, estimator.labels_),
                 metrics.adjusted_rand_score(labels, estimator.labels_),
                 metrics.adjusted_mutual_info_score(labels, estimator.labels_),
                 metrics.silhouette_score(data, estimator.labels_,
                                          metric='euclidean',
                                          sample_size=sample_size)))

    bench_k_means(KMeans(init='k-means++', n_clusters=n_digits, n_init=10),
                  name="k-means++", data=data)

    bench_k_means(KMeans(init='random', n_clusters=n_digits, n_init=10),
                  name="random", data=data)

    # in this case the seeding of the centers is deterministic, hence we run the
    # kmeans algorithm only once with n_init=1
    pca = PCA(n_components=n_digits).fit(data)
    bench_k_means(KMeans(init=pca.components_, n_clusters=n_digits, n_init=1),
                  name="PCA-based",
                  data=data)
    print(79 * '_')

    ###############################################################################
    # Visualize the results on PCA-reduced data

    reduced_data = PCA(n_components=2).fit_transform(data)
    kmeans = KMeans(init='k-means++', n_clusters=n_digits, n_init=10)
    kmeans.fit(reduced_data)

    # Step size of the mesh. Decrease to increase the quality of the VQ.
    h = .02  # point in the mesh [x_min, m_max]x[y_min, y_max].

    # Plot the decision boundary. For that, we will assign a color to each
    x_min, x_max = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
    y_min, y_max = reduced_data[:, 1].min() - 1, reduced_data[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # Obtain labels for each point in mesh. Use last trained model.
    Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(1)
    plt.clf()
    plt.imshow(Z, interpolation='nearest',
               extent=(xx.min(), xx.max(), yy.min(), yy.max()),
               cmap=plt.cm.Paired,
               aspect='auto', origin='lower')

    for x, y, z in zip(reduced_data[:, 0], reduced_data[:, 1], all_labels):
        if z != '$TM$' and z != '$Tm$':
            plt.plot(x, y, 'k.', marker='.', alpha=.4)
#             plt.plot(x, y, 'k.', marker=z, markersize=10, alpha=.5)
        elif z == '$TM$':
            plt.plot(x, y, 'k.', marker=z, color='white', markeredgecolor='none', markersize=10)
            plt.plot(x, y, 'k.', marker='^', color='white', markeredgecolor='none', markersize=25)
        elif z == '$Tm$':
            plt.plot(x, y, 'k.', marker=z, color='white', markeredgecolor='none', markersize=10)
            plt.plot(x, y, 'k.', marker='v', color='white', markeredgecolor='none', markersize=25)        
        # plt.plot(x, y, 'k.')

    # for x in alf_labels:
    #         plt.plot(reduced_data[:, 0], reduced_data[:, 1], 'k.', marker = x, markersize=5)
    #     print('reduced data:', reduced_data)
    # Plot the centroids as a white X
    centroids = kmeans.cluster_centers_
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=169, linewidths=3,
                color='w', zorder=10)
    plt.title('K-means clustering of the corpus (PCA-reduced data)\n'
              'Centroids are marked with white cross')
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.xticks(())
    plt.yticks(())
    plt.show()

# %%
def neato_graph(list_of_lists, label_lists):
    dt = [('len', float)]

    A = (np.array(list_of_lists)/2).view(dt)

    G = nx.from_numpy_matrix(A)
    relabeled_nodes = {}
    for x, y in zip (range(len(label_lists)), label_lists):
        relabeled_nodes[x] = y[1:-1]
    G = nx.relabel_nodes(G, relabeled_nodes)

    G = to_agraph(G)

    G.node_attr.update(color="green", style="filled", fontsize=30)
#     G.edge_attr.update(color="black", width=0.5)
    G.edge_attr.update(color='black', style='invis', width=0)
    # G.graph_attr.update(landscape='true', ranksep='0.1')
    
#     ionian=G.get_edge('0:0','-1:5')
#     ionian.attr['color']='blue'
#     ionian.attr['style']='bold'
    
#     dorian=G.get_edge('0:0','-1:5')
#     dorian.attr['color']='blue'
#     dorian.attr['style']='bold'
    
#     ionian=G.get_edge('0:0','-1:5')
#     ionian.attr['color']='blue'
#     ionian.attr['style']='bold'
    
#     ionian=G.get_edge('0:0','-1:5')
#     ionian.attr['color']='blue'
#     ionian.attr['style']='bold'
    
#     ionian=G.get_edge('0:0','-1:5')
#     ionian.attr['color']='blue'
#     ionian.attr['style']='bold'
    
#     ionian=G.get_edge('0:0','-1:5')
#     ionian.attr['color']='blue'
#     ionian.attr['style']='bold'
    
    G.draw('/home/daniel/Desktop/neato_alf.png', format='png', prog='neato')
    G.draw

# %%
def neato_maker(lists_tuple):
    DIST = []
    for x in lists_tuple[0]:
        dist_temp = []
        for y in lists_tuple[0]:
            dist_temp.append(euclidean(x, y))
        DIST.append(dist_temp)
    return DIST, label_maker(lists_tuple[1])

# %%
X = neato_maker(alf_ave)

# %%
neato_graph(X[0], label_maker_alf(alf_ave[1]))

# %%
fingering

# %%
k_means_data(palestrina_notes_data, 6, palestrina_labels)

# %%
for x in range(2, 15):
    print(x, 'yields', k_means_data(palestrina_notes_data, x, palestrina_labels)[1])

# %%
all_data = []
for x in alfabeto_notes_data[0]:
    all_data.append(x)
    
# for x in josquin_notes_data[0]:
#     all_data.append(x)
    
for x in bach_notes_data[0]:
    all_data.append(x)
    
# for x in palestrina_notes_data[0]:
#     all_data.append(x)
    
# for x in dufay_notes_data[0]:
#     all_data.append(x)

# for x in monteverdi_notes_data[0]:
#     all_data.append(x)
    
all_dataL = []

for x in alfabeto_notes_data[1]:
    all_dataL.append('$A$')
    
# for x in josquin_notes_data[1]:
#     all_dataL.append(x)
    
for x in bach_notes_data[1]:
    all_dataL.append('$B$')
    
# for x in palestrina_notes_data[1]:
#     all_dataL.append(x)
    
# for x in dufay_notes_data[1]:
#     all_dataL.append(x)

# for x in monteverdi_notes_data[1]:
#     all_dataL.append(x)

watch = (all_data, all_dataL)

# %%
# %matplotlib qt
k_means_data(watch[0], 2, watch[1])
