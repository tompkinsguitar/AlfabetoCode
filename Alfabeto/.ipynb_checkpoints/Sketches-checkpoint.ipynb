# %%
from Continuo.ContinuoMarkov import scale_degree_harmonization, scale_degree_harmonization_song
from Continuo.kmeans_inversion import k_means_data, silhouette_analysis
from alfabeto_sources.all_sources import *

import csv

# %%
def figure_sorter(function):
    final_data = []
    other_numbers = []
    figures = [[0, 4, 7], [0, 3, 7], [0, 3, 8], [0, 4, 9], [0, 5, 9], [0, 5, 8]]
    for figure in figures:
        figure_list = []
        for number in range(12):
            fig = str([number, figure])
            if fig in function:
                figure_list.append(function[fig])
            else:
#                 figure_list.append('-')
                figure_list.append(0)
        final_data.append(figure_list)
    for number in range(12):
        numbers = 0
        for x, y in function.items():
            if x[1:3] == str(number) and x[-10:-1] not in str(figures):
                numbers += y
            elif x[1:2] == str(number) and x[-10:-1] not in str(figures):
                numbers += y
        other_numbers.append(numbers)
    other_final = []
    for x in other_numbers:
        if x > 0:
            other_final.append(x)
        else:
            other_final.append('-')
#     final_data.append(other_final) # if you want dashes instead of 0's
    final_data.append(other_numbers) # if you want 0's instead of dashes
    return final_data

# %%
def inversion_kmeans(corpus, mode_list):
    all_modes = []
    if mode_list == 'all':
        each_mode = [('f', 0), ('f',2), ('f',5), ('f',7), ('f',9), ('f',10), ('n',0), ('n',2), ('n',4), ('n',5), ('n',7), ('n',9)]
        for x in each_mode:
            all_modes.append(x)
    else:
        for x in mode_list:
            all_modes.append(x)
    labels = []
    final_labels = []
    final_songs = []
    final_songs_reduced = []
    for x in all_modes:
        for y in corpus:
            for z in y.values():
                if z['data']['key'] == x[0] and z['data']['final'] == x[1]:
                    temp_list = []
                    matrix_data = (figure_sorter(scale_degree_harmonization_song(z, x)))
                    for a in matrix_data:
                        for b in a:
                            temp_list.append(b)
                    final_songs.append(temp_list)
                    labels.append(x)
    for x in labels:
        if x == ('f',2):
            final_labels.append('$♭:D$')
        elif x == ('n',4):
            final_labels.append('$♮:E$')
        elif x == ('n',9):
            final_labels.append('$♮:A$')
        elif x == ('f',7):
            final_labels.append('$♭:G$')
        elif x == ('n',2):
            final_labels.append('$♮:D$')
        elif x == ('f',9):
            final_labels.append('$♭:A$')
        elif x == ('f',0):
            final_labels.append('$♭:C$')
        elif x == ('f',10):
            final_labels.append('$♭:B♭$')
        elif x == ('n',5):
            final_labels.append('$♮:F$')
        elif x == ('n',0):
            final_labels.append('$♮:C$')
        elif x == ('f',5):
            final_labels.append('$♭:F$')
        elif x == ('n',7):
            final_labels.append('$♮:G$')
        elif x == 'Temperley MAJOR':
            final_labels.append('$Temperley MAJOR$')
        elif x == 'Temperley MINOR':
            final_labels.append('$Temperley MINOR$')
        else:
            final_labels.append('o') 
    for x in final_songs:
        for y in x:
            final_songs_reduced.append(y)
    
    return (final_songs, final_labels)

# %%
inversion_data = inversion_kmeans(GetAll.all_alf, 'all')
# inversion_data = inversion_kmeans(GetComposer.all_stefani, [('f', 2), ('n', 2)])
# Out:
# number of chords 38
# number of chords 116
# number of chords 32
# number of chords 85
# number of chords 63
# number of chords 81
# number of chords 96
# number of chords 65
# number of chords 92
# number of chords 82
# number of chords 95
# number of chords 65
# number of chords 122
# number of chords 53
# number of chords 110
# number of chords 85
# number of chords 95
# number of chords 126
# number of chords 61
# number of chords 125
# number of chords 85
# number of chords 106
# number of chords 63
# number of chords 71
# number of chords 112
# number of chords 97
# number of chords 109
# number of chords 116
# number of chords 81
# number of chords 100
# number of chords 120
# number of chords 95
# number of chords 90
# number of chords 121
# number of chords 182
# number of chords 142
# number of chords 55
# number of chords 27
# number of chords 69
# number of chords 81
# number of chords 71
# number of chords 90
# number of chords 133
# number of chords 62
# number of chords 74
# number of chords 96
# number of chords 94
# number of chords 50
# number of chords 55
# number of chords 60
# number of chords 62
# number of chords 178
# number of chords 109
# number of chords 106
# number of chords 71
# number of chords 66
# number of chords 47
# number of chords 49
# number of chords 67
# number of chords 57
# number of chords 36
# number of chords 50
# number of chords 48
# number of chords 155
# number of chords 93
# number of chords 156
# number of chords 83
# number of chords 17
# number of chords 124
# number of chords 108
# number of chords 134
# number of chords 101
# number of chords 125
# number of chords 93
# number of chords 67
# number of chords 35
# number of chords 65
# number of chords 89
# number of chords 131
# number of chords 77
# number of chords 32
# number of chords 109
# number of chords 77
# number of chords 87
# number of chords 42
# number of chords 58
# number of chords 74
# number of chords 57
# number of chords 43
# number of chords 41
# number of chords 48
# number of chords 39

# %%
# %matplotlib inline
# PSA = k_means_data(inversion_data[0], 3, inversion_data[1])
k_means_data(inversion_data[0], 2, inversion_data[1])
# k_means_data(inversion_data[0], 3, inversion_data[1])
# k_means_data(inversion_data[0], 12, inversion_data[1])
# Out:
# n_digits: 2, 	 n_samples 460, 	 n_features 84
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.03s    142116   0.113   1.000   0.203   0.000   -0.000    0.319
#    random   0.03s    142116   0.113   1.000   0.203   0.000   -0.000    0.319
# PCA-based   0.00s    142120   0.113   1.000   0.203   0.000   -0.000    0.319
# _______________________________________________________________________________
# array([[-11.76682517,   8.56027054],
#        [-16.58593494,   5.42956531],
#        [ -4.74127385,  -4.94468236],
#        [  0.46220974,  10.15427147],
#        [-14.33867461,  -6.57092711],
#        [-16.38435975,  -4.41313096],
#        [-14.63065045,  -9.11487922],
#        [ -9.87446534,   1.89176312],
#        [-15.12812205,  -3.45812993],
#        [-23.59819443,   0.88326101],
#        [-17.63831404,  -1.539984  ],
#        [-17.97374611,  -3.44313621],
#        [-12.0141798 ,  -7.25775204],
#        [-18.76633262,  -2.85617987],
#        [-14.24621894,  -0.1588469 ],
#        [-14.08457269,  -8.56349225],
#        [-21.32536799,  -2.4986395 ],
#        [-14.49378277,  -8.96919526],
#        [-16.67898685,  -7.61086156],
#        [-13.81969777, -10.46163534],
#        [ -9.70410278,  -4.58809693],
#        [-14.69460185,  -8.09432101],
#        [ 15.70835308,   1.10767332],
#        [ 17.0489674 ,  -1.37889057],
#        [ 16.99741604,   2.23104543],
#        [ 16.82698646,   4.27500015],
#        [ 12.98066777,   2.64596344],
#        [ 12.68779461,  -1.49655396],
#        [ 14.30306839,  -1.3912226 ],
#        [ 14.00407738,  -1.82817892],
#        [ 19.46249016,  -6.42563593],
#        [ 11.0854331 ,  -2.54150869],
#        [ 12.84283689,   0.9873736 ],
#        [ 14.71739837,  -1.01262506],
#        [ 14.38880874,  -1.54152294],
#        [ 17.21481929,  -2.65119542],
#        [ 10.05668899,   2.75740517],
#        [  9.97225956,   4.86387031],
#        [ 16.29108595,  -3.53132735],
#        [-14.52398039,  -4.98597764],
#        [-13.5032382 ,  -0.37394016],
#        [ -5.95507654,  -0.5510541 ],
#        [ -7.94735445,  -9.57041398],
#        [-24.52975191,  -6.89706775],
#        [-10.8772629 ,  -7.93953402],
#        [-22.40992167,   4.40787856],
#        [-12.60221843,  11.85125469],
#        [ 13.12027182,  -2.76845368],
#        [-14.83585462,   7.3943057 ],
#        [-16.30449065,   6.49344115],
#        [-17.92246656,   6.19394037],
#        [-12.92820447,   4.56374418],
#        [-10.49199791,   2.74478378],
#        [ -6.54475399,   0.10595215],
#        [ -8.1571663 ,  -1.76617871],
#        [-11.1986073 ,   3.86973983],
#        [ -8.22119982,  -9.30994299],
#        [-17.66733245,   5.58528386],
#        [ -7.45349088,  10.95769357],
#        [-12.28259678,   2.29400215],
#        [-19.33917074,  -1.24403469],
#        [-20.23190176,   4.26260393],
#        [-13.40225961,   7.23368358],
#        [-12.95315663,   3.35301069],
#        [-10.36839579,   6.85915263],
#        [-10.37880022,   0.95609379],
#        [-12.53213937,  -5.08509803],
#        [-15.05903262,  -1.04566912],
#        [-14.8626457 ,   1.87386988],
#        [-11.92233735,  -9.05125852],
#        [-15.13745426,   4.59973782],
#        [-10.15491728,  10.58534585],
#        [-16.05634907,   5.17477335],
#        [-17.77085343,   2.2740071 ],
#        [-14.84727767,   2.6291797 ],
#        [-11.04754361,  -0.95149387],
#        [-11.4851428 ,  -3.81186984],
#        [-17.768664  ,  -2.13107065],
#        [-12.24705694,   4.39018937],
#        [-13.00531594,   2.35723556],
#        [-13.32532425,  -8.75200379],
#        [-13.13806245,  -3.10702528],
#        [-23.09388147,   7.11949675],
#        [-12.69400915,  -0.04493972],
#        [-14.67830058,   4.62708008],
#        [-14.9033324 ,   3.68774861],
#        [-16.54130164,   5.22255932],
#        [-22.30598378,   0.99756404],
#        [-16.50111615,  11.78760281],
#        [-15.61256907,   1.93532205],
#        [-12.09698862,   5.19769006],
#        [-19.54256746,  -0.56704468],
#        [-11.9563694 ,   3.76628975],
#        [-16.82371923,   6.10325686],
#        [-16.63611434,  21.7646996 ],
#        [-18.82243075,   7.23311024],
#        [-17.50124156,   5.17654096],
#        [-19.64032324,   1.90468434],
#        [-20.77725267,   6.61877348],
#        [-19.95873065,   3.25670806],
#        [-19.53412882,   1.65757642],
#        [-17.1048715 ,   0.86081875],
#        [-15.51291585,   2.52399836],
#        [-14.47645837,   3.75629245],
#        [-15.09482196,   1.07871422],
#        [-20.71548897,  -6.4239049 ],
#        [-17.60607803,   4.61735499],
#        [-17.1072455 ,   3.53082528],
#        [-20.05231037,  -1.99606972],
#        [ -7.23519668,  -3.68023862],
#        [-17.85529992,  -1.04719504],
#        [-12.60923748,   2.21045921],
#        [-15.38989469,   4.96465021],
#        [-20.28253007,  -9.80266262],
#        [-13.94138353,  -0.08562125],
#        [-15.8843906 ,  -3.37219605],
#        [-11.9528431 ,  -4.39033576],
#        [-15.54697726,  -2.36283482],
#        [-13.02674671,  -3.31942572],
#        [ -5.59164263,  -0.89899494],
#        [-12.54666673,  -4.32058993],
#        [ -8.86448111,   0.40485775],
#        [ -9.02609471,   2.49939529],
#        [-15.42449746,  -1.65841957],
#        [ -5.73272277,   2.21577014],
#        [  8.57625646,   1.37671051],
#        [ -5.41585809,  -3.32589328],
#        [ -9.11667779,  -2.65817148],
#        [ -7.96955004,  -0.72450722],
#        [ -6.06109118,  -1.82860568],
#        [ -5.20391019,   0.20699889],
#        [-20.03927716,   9.38507153],
#        [-21.78005342,  -4.12784837],
#        [-23.05384971,  -4.31142896],
#        [-20.8903388 ,  -1.57426885],
#        [-14.37244871,   1.85910002],
#        [-12.82841258,  -7.2572794 ],
#        [ -9.40118902,  -1.26962474],
#        [-17.77697914,  -1.51717273],
#        [ -5.74346595,  -2.70716031],
#        [-12.92208002,  -1.11241846],
#        [-12.12182222,   0.93307766],
#        [-15.79504847,   5.32131535],
#        [-10.99085394,  -0.79279662],
#        [ -8.94427079,  -8.5854324 ],
#        [-15.32762405,   1.0268623 ],
#        [  3.17444431,   4.49139944],
#        [-18.120669  ,  -8.89226157],
#        [ -9.50021126,   1.42843964],
#        [ -9.1423745 ,   0.73695759],
#        [-12.06205873,   3.06017741],
#        [ -4.93295836,  -4.02455836],
#        [ -4.93770438, -12.65945007],
#        [-15.49549046,  -0.48990789],
#        [-14.70533635,  -7.36495935],
#        [-23.22914236,   2.12857504],
#        [-11.85770341,   1.31442862],
#        [ -2.83202606,  -7.98335261],
#        [-10.99135919,   5.04839457],
#        [-12.30960339,   7.02195854],
#        [ -6.84457438,   1.46446226],
#        [ -9.62745154,   7.65711439],
#        [ -7.51205475,   2.2906476 ],
#        [-10.46543878,   1.43903755],
#        [-10.50010863,   6.39751472],
#        [ -8.65962243,  -2.08438147],
#        [-20.09258397,   0.19376753],
#        [ -5.4919235 ,   1.61584844],
#        [ -3.81750846,  -3.98471142],
#        [ -9.46813625,  -3.32426112],
#        [  8.23378912,  -1.21022549],
#        [ 12.75654257,   0.11737709],
#        [ 17.2530018 , -14.3565781 ],
#        [ 23.04523366, -11.87077805],
#        [ 16.95969351, -13.0402687 ],
#        [  7.51342029,  -4.19455503],
#        [ 27.9181012 , -15.29583707],
#        [ 18.06091759,  -3.32613508],
#        [ 15.43138755,   0.16882644],
#        [  9.97468812,   3.16450908],
#        [ 13.63461483,  -5.91416304],
#        [ 15.87169125,  -6.28984258],
#        [ 15.76179549,  -1.26504117],
#        [ 10.03133473,   9.02479128],
#        [  9.64896897,   7.75338212],
#        [ 12.33234249,  -9.48694237],
#        [  9.02035256,  -9.94713561],
#        [ 14.76446419,  -0.48962803],
#        [  6.71332929,   3.87498501],
#        [ 15.35554177,   1.14483261],
#        [ 15.83673952,   1.07901667],
#        [  9.17716721,  -1.72108115],
#        [ 15.03913507,  -7.02783526],
#        [ 16.45034029,  -4.65473033],
#        [ 15.2141782 ,  -5.45960329],
#        [ 14.0899758 ,  -4.20960983],
#        [  9.91951124,   0.899862  ],
#        [ 15.51315297,  -5.73801304],
#        [ 15.38375256,  -0.13185275],
#        [ 23.36768224, -10.97831364],
#        [ 16.21345255, -10.09035968],
#        [ 19.94101123, -10.74995989],
#        [ 12.19140494,  -5.3148765 ],
#        [ 11.19399523,  -6.14314662],
#        [ 10.69625412,  -5.6709319 ],
#        [-18.96220519, -10.43734559],
#        [-11.68448016,   1.95458219],
#        [ -6.13088493,  -0.89268431],
#        [-17.40715173,   0.25077344],
#        [-14.42517297,  -1.3476063 ],
#        [-22.63346876,  -7.68398284],
#        [ 12.61271282,  -3.12386368],
#        [-19.97391388,   5.17421144],
#        [ -4.98899692,  -4.23923223],
#        [-11.45556116, -11.39767394],
#        [-14.91865213,  -8.37092581],
#        [ -7.04902952,   3.32480161],
#        [-14.03286416,   1.25373365],
#        [-12.53491818,  -1.52696968],
#        [ -2.10345529,  -1.10665464],
#        [-10.75455821,  -1.61542279],
#        [ -0.82063024,   1.28475078],
#        [ -5.03229903, -10.79663424],
#        [ -8.62485975,  -2.43452653],
#        [  5.27770272,  -5.43949861],
#        [-11.93196128,  -5.89378557],
#        [-12.18075374,  -4.53118727],
#        [ -8.3697077 ,   7.76626853],
#        [  8.62985923,  -9.76666325],
#        [-14.41165225,  -0.10819893],
#        [-19.38874881,  -0.38424165],
#        [ 13.5688905 ,  -3.87946724],
#        [-17.20485384,   1.01073458],
#        [-13.16678832,  -0.26284075],
#        [ -0.06315379,   7.05371124],
#        [-13.51717596,   9.00925098],
#        [-14.73571477,   1.89090277],
#        [-19.09606654,   5.92883885],
#        [-13.91094133,   2.87334427],
#        [-18.84788721,  -1.53225078],
#        [-22.49090316,   7.01516407],
#        [-17.77007308,  12.86874933],
#        [-19.0595442 ,   1.78676333],
#        [-20.66098226,   0.05847583],
#        [-14.13971032,  -6.08942321],
#        [-17.47770927,  -1.16762418],
#        [-11.60501857,  -2.65897119],
#        [ -3.81885742,   1.9972436 ],
#        [-19.58580856,  -7.75878358],
#        [-22.07780938,  -5.15355298],
#        [-19.49006427,  -4.59992175],
#        [-15.32905913,  -8.24476958],
#        [-10.01322733,  -8.87796619],
#        [ 16.74474108,  -3.52187168],
#        [ 17.43318208, -15.43989684],
#        [ 12.98355214,  -3.90359652],
#        [  8.41204795,  -7.52574514],
#        [ 15.3630644 ,   7.59659916],
#        [ 15.73719601,   5.00071287],
#        [ 12.637339  ,   4.81507522],
#        [ 19.54013389, -13.8437873 ],
#        [  6.21086146,   7.21218768],
#        [ 10.73634256,  -4.69025462],
#        [  7.59957702,   3.77425973],
#        [ 10.9926501 ,  -5.69766026],
#        [ 21.70193322,  -6.69733742],
#        [  9.91226624,   8.82171531],
#        [ 12.38996082,   3.06924286],
#        [ 13.1222533 ,   0.25518197],
#        [ 11.96382793,   0.87949155],
#        [ 16.73245319, -13.9393706 ],
#        [ 13.61666287,   3.62428619],
#        [ 12.32903501,   8.59863967],
#        [ 13.37862623,   2.65257752],
#        [ 13.95789714,   4.8756029 ],
#        [  7.88206508,  13.2058226 ],
#        [ 15.14007714,   4.10691297],
#        [ 16.96012526,   5.77633353],
#        [ 11.65216609,  10.5198556 ],
#        [  8.11809947,  12.69842637],
#        [ 15.13606795,   2.84523671],
#        [ 12.63596687,   9.61352791],
#        [  9.86633274,   4.46048656],
#        [ 10.06689828,  13.31795747],
#        [ 14.06622872,  -3.45909609],
#        [ 13.95220456,  13.77120681],
#        [ 16.22256024,   5.26240338],
#        [ 10.8267866 ,   7.74256007],
#        [ 17.75952024,   2.48440823],
#        [ 12.50459648,   4.98790872],
#        [ 11.79084896,   5.08400016],
#        [ 15.17695863,   3.61997418],
#        [ 19.08607423,  -7.69000017],
#        [  9.05143643,   7.29753774],
#        [ 14.08413721,   5.08894807],
#        [ 13.64521019,   1.2184067 ],
#        [ -0.82339329,   9.36056097],
#        [  7.41040748,   7.3024788 ],
#        [  6.32122644,   9.32330811],
#        [ -1.65407179,   4.92141068],
#        [ 11.1180167 ,  -2.7802291 ],
#        [  7.89092873,  18.56971748],
#        [ 10.57645354,  -1.61136185],
#        [ 11.5063806 ,  -0.53268124],
#        [ 13.35824959,   1.19613547],
#        [  3.00399068,   8.14430043],
#        [ 12.68595407,   0.41509596],
#        [  0.22143548,  13.83788869],
#        [  5.98938078,   8.53989128],
#        [ -1.23996114,   5.95380946],
#        [  7.91228033,   8.61835107],
#        [ 15.10810475,   7.66493671],
#        [  4.57535743,   5.26943992],
#        [  3.1959156 ,   4.48063648],
#        [  7.38029258,   9.15575485],
#        [ 10.6476564 ,   8.73829737],
#        [  8.8724521 ,  11.41695451],
#        [ 10.7595226 ,  -4.21074474],
#        [ 11.36872903,   2.21926943],
#        [  3.93840042,  12.92408319],
#        [  9.86929425,  -1.5459621 ],
#        [ 15.61112353,  -8.56486477],
#        [  9.8568583 ,   3.00936545],
#        [  6.08399269,  -0.9954971 ],
#        [ 10.80294029,   1.12520387],
#        [  5.00756372,   6.80539338],
#        [  7.56764189,   7.41422487],
#        [  1.53006768,   8.0461495 ],
#        [  6.13900593,   5.08474472],
#        [ 16.32530336,  -1.32939313],
#        [ 27.02736755, -23.43605311],
#        [ 13.1575859 ,  -0.25398583],
#        [ 19.48899379,  -8.68940323],
#        [ 17.18422668,  -8.82938206],
#        [ 11.92290882,   0.25933779],
#        [ 10.12768119,  -1.82080251],
#        [ 15.80701131, -12.54872472],
#        [ 11.86438186,   4.08061954],
#        [  7.29609822,   6.10866118],
#        [  8.55759455,  -4.4299152 ],
#        [ 16.38605605,   5.37430739],
#        [ 13.20239448,   9.17912951],
#        [  9.57474294,  -0.87604434],
#        [ 12.8404615 ,  -3.98884232],
#        [  7.79107896,   0.93156068],
#        [  9.10028333,   8.76478901],
#        [  2.53316809,   1.46189122],
#        [  9.43887801,  -1.02443372],
#        [ 16.50300445,  -3.8451987 ],
#        [ 12.76824124,   4.20229892],
#        [ -5.01842481,  -2.62421482],
#        [  8.08436828,   5.23877454],
#        [ 17.98953211,   6.85590423],
#        [ 18.81851853,  -8.27994248],
#        [ 15.86509428,  -1.60115574],
#        [  6.74620523,   0.62173385],
#        [ 11.3259895 ,   5.01874449],
#        [ 19.3248055 ,   1.17793919],
#        [  7.51779145,   3.76784128],
#        [ 18.00251046,  -9.25045978],
#        [ 26.73894951, -20.7384577 ],
#        [-21.23936256,  -6.98323098],
#        [-18.52785282,  -4.48291645],
#        [-11.35385456, -12.94527094],
#        [ -4.10481158, -11.76687496],
#        [-16.66763801, -14.30376576],
#        [ -4.54514727, -11.13879248],
#        [-21.41691823,   1.57366291],
#        [  1.54565948, -18.75395014],
#        [-24.41701646,  -2.82347211],
#        [ -5.35910743,  -0.51809259],
#        [-11.11697885,  -5.60620062],
#        [ -5.44385769,  -0.85167959],
#        [ -2.73287049, -11.81141768],
#        [ -6.19383236,  -1.76515244],
#        [-13.97658951,  -1.43740281],
#        [-20.79755858,   0.69381089],
#        [-25.78726483,  -2.85590438],
#        [-28.28159518,  -7.12655982],
#        [ -3.5522286 ,  -8.83509172],
#        [-20.07391043,   1.50597639],
#        [-21.39381744, -10.19428674],
#        [-13.95899497,  -5.76722173],
#        [-12.77155267, -13.41503504],
#        [ -3.04055779,  -6.23212759]])

# %%
silhouette_analysis(PSA, 6)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.634103748865
# For n_clusters = 3 The average silhouette_score is : 0.502237116706
# For n_clusters = 4 The average silhouette_score is : 0.381955338979
# For n_clusters = 5 The average silhouette_score is : 0.378110897714

# %%
scale_degree_harmonization(GetAll.all_alf, ('n', 7))

# %%
CSV_DATA = figure_sorter(scale_degree_harmonization(GetAll.all_alf, ('n', 7)))

# %%
with open('/home/daniel/Dropbox/Dissertation/Images/Octave Harmonization/csv_files/all_kaps_n7.csv', 'w', newline='') as fp:
    a = csv.writer(fp, delimiter=',')
    final_data = CSV_DATA
    a.writerows(final_data)

# %%
a = '[0, [2, 7, 0]]'

# %%
b = [0, [2, 7, 0]]

# %%
'0' in str(b)
