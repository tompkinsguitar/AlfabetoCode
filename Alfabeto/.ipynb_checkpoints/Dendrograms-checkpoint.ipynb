# %%
import alfabeto_data.dissertation_images as di
from alfabeto_sources.all_sources import *
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
# Out:
# ready!

# %%
bi_function = di.bigram_numbers_continuo(di.GetAll.all_alf, di.modal_major)
bi = di.function_thing(bi_function, 'not_numerals')

# %%
np.array(bi[2])
print(bi[2])

# %%
plt.figure(figsize=(6,3))
plt.title('Root Clustering')
plt.xlabel('Chord Roots')
plt.ylabel('Difference')
X = np.array(bi[2])
print(X.shape)
Z = linkage(X, 'ward')
newlabels = []
for label in bi[1]:
    for a, b in di.numerals_to_data.items():
        if label == b:
            print(ja)
            newlabels.append(a)
        else:
            newlabels.append(b)
dendrogram(Z, leaf_font_size=14, labels=bi[1])
print(bi[1])
# dendrogram(Z, leaf_font_size=14, labels=f_labels)
# plt.savefig('/home/daniel/Dropbox/Dissertation/Latex/figures/function/dendrograms/dendrogram_alfabeto_roots_major.pdf', 
#             bboxinches='tight')

plt.show()
plt.close()

# %%
print(bi[1])

# %%
f_labels = ['IV$^6$', r'$\flat$VII', r'$\flat$III', 'ii', r'$\flat$III$^6$', 'V', r'$\flat$VI', 
            'IV', 'i', 'I', 'II', 'iv', r'$\flat$VII$^6$', 'v']

# %%
di.k_means_data(bi[2], 3, , '/home/daniel/Desktop/kmeans_bach.pdf')

# %%
f = []
for x in bi[0]:
    f.append([y/sum(x)*100 for y in x])

# %%
l = []
for x in bi[1]:
    l.append('$'+x+'$')

# %%
cons = []
ant = []
labels = ['$'+x+'$' for x in bi[1]]
antarray = np.array(bi[0])
for x in range(len(bi[0])):
    ant_number = antarray[:,x]
    ant.append([y/(sum(ant_number)+sum(bi[0][x]))*100 for y in ant_number])
    cons.append([y/(sum(ant_number)+sum(bi[0][x]))*100 for y in bi[0][x]])
for a, b in zip(cons, ant):
    for x in b:
        a.append(x)

# %%
bi[1]

# %%
di.k_means_data(cons, 3, labels, '/home/daniel/Desktop/kmeans_alf.pdf')

# %%
plt.figure(figsize=(7,4))
plt.title('Chord Clustering')
plt.xlabel('Chords')
plt.ylabel('Difference')
X = np.array(cons)
print(X.shape)
Z = linkage(X, 'ward')
dendrogram(Z, leaf_font_size=14, labels=f_labels)
# dendrogram(Z, leaf_font_size=14, labels=f_labels)
# plt.savefig('/home/daniel/Dropbox/Dissertation/Latex/figures/function/dendrograms/dendrogram_alfabeto_continuo_minor.pdf', 
#             bboxinches='tight')

plt.show()
plt.close()

# %%
Y = di.neato_maker((cons, l))

# %%
di.neato_plain(Y[0], l, '/home/daniel/Desktop/neatoboth.pdf')

# %%
X

# %%
from matplotlib import pyplot as plt

# %%
labels = ['I', 'I6', 'II', 'ii', 'III', 'iii', 'IV', 'IV6', 'V', 'V6', 'v', 'VI', 'vi', 'bVII']

T = [.99, .97, 0, 0, 0, .98, 0, .68, .55, 1, .74, 0]
S = [0, 0, 1, .65, 0, 0, 1, .24, 0, .36, 0, 0, .26, .12]
D = [0, 0, 0, .35, 1, 0, 0, 0, 1, .6, .45, 0, 0, .82]

plt.plot(T, color='red')
plt.plot(S, color='yellow')
plt.plot(D, color='blue')
plt.xticks([x for x in range(len(labels))], labels)
plt.show()

# %%
from alfabeto_data.AlfabetoStats.stats import *
from alfabeto_sources.all_sources import *
from alfabeto_data.AlfabetoStats.Bach_Choral_Chords import bach_all_chorales

# %%
def chordFQ(comparison_dict, mode, progression_element, tab):
    # k1, k2, k3, k4, sanz1
    source_percentages = []
    labels = []
    # for x in comparison_list:
    #     source_list.append(chord_frequency([x], mode, progression_element, tab))
    if type(comparison_dict) == list:
        for numeral in numerals:
            # print('this is bach')
#             print(x)
            source_percentages.append(chord_frequency(comparison_dict, mode, 'all', 'bach')[numeral])
#             source_percentages.append(temp_list)
        print(source_percentages)
    else:
        for label, book_list in comparison_dict.items():
            labels.append(label)
            temp_list = []
            for x in book_list:
    #             temp_list = []
                for numeral in numerals:
                    if type(x) == list:
                        # print('this is bach')
                        temp_list.append(chord_frequency(x, mode, 'all', 'bach')[numeral])
                    else:
                        # print('not bach')
                        temp_list.append(chord_frequency([x], mode, progression_element, tab)[numeral])
            source_percentages.append(temp_list)
        print(source_percentages)
#     A = np.array(source_percentages)
#     from scipy.spatial.distance import cdist
#     source_distances = cdist(source_percentages, source_percentages, metric='euclidean')
#     # for x in source_percentages:
#     #     distance_list = []
#     #     for y in source_percentages:
#     #         distances = euclidean(x, y)
#     #         # distances = cosine(x, y)*1000
#     #         # distances = 100 - pearsonr(x, y)[0] * 100
#     #         distance_list.append(distances)
#     #     source_distances.append(distance_list)
#     print(source_distances)
#     A = source_distances
#     print('A', A)
    return source_percentages, labels

# %%
X = chordFQ(composer_labels_linebreak, di.modal_major, 'all', 'guitar')
# bach = chordFQ(bach_all_chorales, 'all', 'all', 'bach')
# Out:
# [[20.212765957446805, 0.0, 0.0, 0.0, 10.638297872340425, 3.1914893617021276, 1.0638297872340425, 0.0, 0.0, 5.319148936170213, 15.957446808510639, 0.0, 0.0, 0.0, 23.404255319148938, 2.127659574468085, 0.0, 0.0, 6.382978723404255, 8.51063829787234, 3.1914893617021276, 0.0, 0.0, 0.0], [22.849462365591396, 0.8064516129032258, 0.0, 0.0, 5.913978494623656, 8.870967741935484, 0.2688172043010753, 0.0, 1.0752688172043012, 2.6881720430107525, 16.93548387096774, 0.2688172043010753, 0.0, 0.0, 17.473118279569892, 2.4193548387096775, 0.0, 0.0, 4.56989247311828, 9.67741935483871, 5.376344086021505, 0.0, 0.2688172043010753, 0.5376344086021506], [21.304347826086957, 4.3478260869565215, 0.0, 0.0, 2.608695652173913, 8.26086956521739, 4.3478260869565215, 0.0, 0.0, 0.0, 17.82608695652174, 1.7391304347826086, 0.0, 0.0, 14.347826086956522, 6.521739130434782, 0.8695652173913043, 0.0, 3.4782608695652173, 5.6521739130434785, 8.695652173913043, 0.0, 0.0, 0.0], [21.15677321156773, 0.15220700152207, 0.0, 0.0, 2.13089802130898, 9.58904109589041, 0.15220700152207, 0.0, 0.91324200913242, 7.76255707762557, 17.35159817351598, 0.0, 0.0, 0.0, 15.220700152207002, 4.41400304414003, 0.0, 0.0, 3.65296803652968, 9.43683409436834, 5.93607305936073, 0.0, 0.15220700152207, 1.97869101978691], [20.87912087912088, 2.197802197802198, 0.0, 0.0, 3.296703296703297, 8.791208791208792, 0.0, 0.0, 9.89010989010989, 0.0, 15.384615384615385, 0.0, 0.0, 0.0, 16.483516483516482, 3.296703296703297, 0.0, 0.0, 12.087912087912088, 4.395604395604396, 3.296703296703297, 0.0, 0.0, 0.0], [24.316109422492403, 3.951367781155015, 0.0, 0.0, 6.079027355623101, 7.90273556231003, 1.21580547112462, 0.0, 0.0, 1.21580547112462, 14.58966565349544, 0.60790273556231, 0.0, 0.0, 20.364741641337385, 3.343465045592705, 0.303951367781155, 0.0, 3.0395136778115504, 7.90273556231003, 5.167173252279635, 0.0, 0.0, 0.0], [23.14814814814815, 5.787037037037037, 0.0, 0.0, 5.092592592592593, 10.87962962962963, 3.009259259259259, 0.0, 0.0, 0.0, 19.212962962962962, 0.0, 0.0, 0.0, 14.814814814814813, 6.712962962962964, 0.0, 0.0, 3.4722222222222223, 0.0, 7.87037037037037, 0.0, 0.0, 0.0], [23.076923076923077, 1.7582417582417582, 0.0, 0.0, 8.571428571428571, 7.032967032967033, 3.5164835164835164, 0.0, 1.5384615384615385, 1.7582417582417582, 15.164835164835164, 0.6593406593406593, 0.0, 0.0, 18.9010989010989, 3.296703296703297, 0.43956043956043955, 0.0, 6.153846153846154, 2.197802197802198, 5.054945054945055, 0.0, 0.21978021978021978, 0.6593406593406593], [20.578778135048232, 0.3215434083601286, 0.0, 0.0, 4.180064308681672, 9.003215434083602, 1.607717041800643, 0.0, 0.0, 6.752411575562702, 16.720257234726688, 0.0, 0.0, 0.0, 14.14790996784566, 6.109324758842444, 0.0, 0.0, 0.6430868167202572, 9.646302250803858, 9.646302250803858, 0.0, 0.6430868167202572, 0.0], [23.414634146341466, 0.24390243902439024, 0.0, 0.0, 6.341463414634147, 6.585365853658537, 0.7317073170731708, 0.0, 0.975609756097561, 3.902439024390244, 17.804878048780488, 1.2195121951219512, 0.0, 0.0, 17.073170731707318, 2.195121951219512, 0.0, 0.0, 5.365853658536586, 6.585365853658537, 6.341463414634147, 0.0, 0.0, 1.2195121951219512], [33.46613545816733, 0.0, 0.0, 0.0, 7.171314741035857, 9.163346613545817, 0.0, 0.0, 1.1952191235059761, 0.0, 14.741035856573706, 0.0, 0.0, 0.0, 20.717131474103585, 3.5856573705179287, 0.0, 0.0, 4.382470119521913, 1.1952191235059761, 4.382470119521913, 0.0, 0.0, 0.0], [25.102319236016374, 0.8185538881309686, 0.0, 0.0, 8.185538881309688, 7.094133697135062, 0.5457025920873124, 0.0, 2.8649386084583903, 2.8649386084583903, 14.188267394270124, 0.0, 0.0, 0.0, 18.826739427012278, 1.5006821282401093, 0.0, 0.0, 6.002728512960437, 5.729877216916781, 5.184174624829468, 0.0, 0.6821282401091405, 0.4092769440654843], [25.850340136054424, 0.6802721088435374, 0.0, 0.0, 9.070294784580499, 5.442176870748299, 0.22675736961451248, 0.0, 0.45351473922902497, 0.22675736961451248, 14.965986394557824, 0.0, 0.0, 0.0, 22.90249433106576, 4.081632653061225, 0.0, 0.0, 3.40 ...

# %%
plt.figure(figsize=(7,10))
plt.title('Book Clustering', fontsize=20)
plt.xlabel('Difference', fontsize=16)
plt.ylabel('Book', fontsize=16)
# X = np.array(cons)
print(np.array(X[0]).shape)
# print(np.array(X[0]))
Z = linkage(np.array(X[0]), 'ward')
dendrogram(Z, leaf_font_size=12, labels=X[1], orientation='right')
# dendrogram(Z, leaf_font_size=14, labels=f_labels)
plt.tight_layout()
plt.savefig('/home/daniel/Desktop/books_minor.pdf', 
            bboxinches='tight')

plt.show()
plt.close()
# Out:
# (29, 24)

# %%
def neato_book(list_of_lists, label_lists, path):
    dt = [('len', float)]
    A = np.array(list_of_lists)
    from scipy.spatial.distance import cdist
    source_distances = cdist(list_of_lists, list_of_lists, metric='euclidean')
    A = (source_distances).view(dt)
    # print(A)
    G = nx.from_numpy_matrix(A)
    relabeled_nodes = {}
    for x, y in zip(range(len(label_lists)), label_lists):
        relabeled_nodes[x] = y
        # print(y[1:-1])
    G = nx.relabel_nodes(G, relabeled_nodes)

    G = to_agraph(G)

    G.node_attr.update(shape='none', fontsize=40)
    G.edge_attr.update(color='black', style='invis')
    #  ♭ ♮ ...for copy and paste

    G.draw(path, format='pdf', prog='neato')

# %%
neato_book(X[0], X[1], '/home/daniel/Desktop/netto_major.pdf')

# %%
X[0]

# %%
for x in X[0]:
    print(len(x))

# %%
a = [1, 2, 3, 4, 5]
b = [1, 1, 1, 1, 1]
c = a+b

# %%
c

# %%
c = [[a], [b]]

# %%
c

# %%
c = [a, b]

# %%
c

# %%
np.mean(c)

# %%
len(bach[0])
# Out:
# 24

# %%
bach_all_chorales
# Out:
# [['I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'vi',
#   'iii',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'I',
#   'IV',
#   'II',
#   'v',
#   'II',
#   'V',
#   'I',
#   'vii',
#   'II',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'II',
#   'v',
#   'II',
#   'V',
#   'I',
#   'vii',
#   'II',
#   'I',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'ii',
#   'v',
#   'VI',
#   'ii',
#   'iii',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'ii',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$vii',
#   '$\\flat$VII',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   '$\\flat$VII',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   '$\\flat$VII',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'ii',
#   'VI',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'vi',
#   'IV',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'IV',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'VI',
#   'ii',
#   'VI',
#   'ii',
#   'v',
#   'ii',
#   'I',
#   'v',
#   'i',
#   'II',
#   'v',
#   'iii',
#   'vi',
#   'v',
#   'I',
#   'vi',
#   'IV',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'III',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'II',
#   'V',
#   'iii',
#   'vi',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   '$\\flat$VII',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'II',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'II',
#   'iii',
#   'ii',
#   'V',
#   'III',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'I',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'v',
#   'II',
#   'V',
#   'I',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VII',
#   'v',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'III',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'III',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'vi',
#   'VI',
#   'ii',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'I',
#   'ii',
#   'V',
#   'I'],
#  ['iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'I',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$iii',
#   '$\\flat$vii',
#   'iv',
#   'I'],
#  ['I',
#   'V',
#   'IV',
#   '$\\flat$VII',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   '$\\flat$VII',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'III',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'ii',
#   '$\\flat$VII',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'I',
#   'ii',
#   'II',
#   'v',
#   'II',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I'],
#  ['i',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VII',
#   'v',
#   'II',
#   'V',
#   'i',
#   'iv',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'ii',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'v',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'v',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'iv',
#   'V',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'I',
#   'v',
#   'I',
#   'iv',
#   'I',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   'i',
#   'v',
#   'iv',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   '$\\flat$III',
#   'II',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VI',
#   'I',
#   'II',
#   '$\\flat$III',
#   'II',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   'i',
#   'I'],
#  ['$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\sharp$iv',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$iv',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   'III',
#   'VI',
#   'VII',
#   'III',
#   '$\\sharp$iv',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\sharp$iv',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$iv',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   'VII',
#   'III',
#   'VI',
#   'VII',
#   'III',
#   '$\\sharp$iv',
#   '$\\flat$VI',
#   '$\\flat$vi',
#   'VI',
#   'III',
#   'VII',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\sharp$iv',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   'VII',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   '$\\flat$ii',
#   'VII',
#   '$\\sharp$IV',
#   'III',
#   'VII',
#   '$\\flat$vi',
#   'VI',
#   'III',
#   'vii',
#   '$\\sharp$iv',
#   '$\\flat$ii',
#   '$\\flat$VI'],
#  ['I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'II',
#   'ii',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'II',
#   'V',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'vii',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   'i',
#   'V',
#   'iv',
#   'V',
#   'i',
#   'I',
#   'IV',
#   'ii',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'I',
#   'vi',
#   'I',
#   'II',
#   'V',
#   'vi',
#   'iii',
#   'IV',
#   'vi',
#   'I',
#   'vi',
#   'I',
#   'vi',
#   'I',
#   'II',
#   'V',
#   'vi',
#   'iii',
#   'IV',
#   'vi',
#   'I',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'iii',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'ii',
#   'IV',
#   'ii',
#   'VI',
#   'ii',
#   'VI',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['iv',
#   '$\\flat$vii',
#   '$\\flat$iii',
#   'IV',
#   'i',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$vii',
#   '$\\flat$iii',
#   'IV',
#   'i',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$iii',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   'iv',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'V',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'VII',
#   'iii',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'VI',
#   'IV',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'ii',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'ii',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'ii',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'II',
#   'vi',
#   'V',
#   'II',
#   'vii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   'VII',
#   '$\\flat$vi',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   'VII',
#   '$\\flat$VI'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$III',
#   'i',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'IV',
#   'ii',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'VI',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'IV',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'IV',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'IV',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'I',
#   'i',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'I'],
#  ['I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'II',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'II',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'V',
#   'iii',
#   'IV',
#   'ii',
#   'II',
#   'V',
#   'IV',
#   'I'],
#  ['i',
#   'V',
#   'IV',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'IV',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$vi',
#   'V',
#   'i',
#   'v',
#   'II',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'V',
#   '$\\flat$VI',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'II',
#   'V',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   'v',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   'iv',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'III',
#   'vi',
#   'IV',
#   'vi',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'iv',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$II',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'vi',
#   'I',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'ii',
#   'I',
#   'iii',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'v',
#   'iv',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vi',
#   'iv',
#   'V',
#   'v',
#   '$\\flat$III',
#   'V',
#   'i',
#   'v',
#   'II',
#   '$\\flat$III',
#   'i',
#   'II',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$III',
#   'I',
#   'iv',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'I',
#   'iv',
#   '$\\flat$II',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'ii',
#   'v',
#   'II',
#   'v',
#   'II',
#   '$\\flat$III',
#   'II',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'v',
#   'V',
#   'i',
#   'iv',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'iii',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'IV',
#   'vi',
#   'ii',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'III',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'III',
#   'IV',
#   'vi',
#   'I',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'II',
#   'V',
#   'iii',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'IV',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'v',
#   'II',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'iii',
#   'vi',
#   'iii',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'VII',
#   '$\\flat$II',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\flat$II',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['$\\sharp$iv',
#   'VII',
#   '$\\sharp$iv',
#   '$\\flat$II',
#   'III',
#   '$\\sharp$iv',
#   'III',
#   'VII',
#   '$\\sharp$iv',
#   '$\\flat$vi',
#   'VI',
#   'III',
#   'VII',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   'VI',
#   'III',
#   '$\\sharp$iv',
#   '$\\flat$ii',
#   'III',
#   '$\\flat$vi',
#   'vii',
#   '$\\flat$II',
#   '$\\sharp$iv',
#   '$\\flat$II',
#   '$\\sharp$iv',
#   '$\\flat$ii',
#   'VI',
#   'III',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$VI'],
#  ['V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i'],
#  ['I',
#   'vi',
#   'V',
#   'iii',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'iii',
#   'IV',
#   'ii',
#   'iii',
#   'V',
#   'IV',
#   'iii',
#   'I',
#   'IV',
#   'iii',
#   'vi',
#   'I',
#   'vi',
#   'V',
#   'iii',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'iii',
#   'IV',
#   'ii',
#   'iii',
#   'V',
#   'IV',
#   'iii',
#   'I',
#   'IV',
#   'iii',
#   'vi',
#   'I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'vi',
#   'III',
#   'VI',
#   'ii',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'I',
#   'IV',
#   'vi',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'v',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'vi',
#   'III',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'vi',
#   'III',
#   'II',
#   'V',
#   'I',
#   'II',
#   'V',
#   'II',
#   'vii',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'V',
#   'vi',
#   'I',
#   'IV',
#   'I'],
#  ['I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   '$\\flat$VII',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'ii',
#   'vi',
#   'ii',
#   'I',
#   '$\\flat$III',
#   'v',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'IV',
#   'I',
#   'ii',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'iii',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'vi',
#   'IV',
#   'I',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'iii',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'v',
#   'i',
#   'v',
#   'iv',
#   '$\\flat$VII',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'v',
#   'i',
#   'v',
#   'iv',
#   '$\\flat$VII',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$II',
#   'iv',
#   '$\\flat$II',
#   'I',
#   'iv',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'iii',
#   'ii',
#   'vi',
#   'ii',
#   'III',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'III',
#   'vi',
#   'IV',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'ii',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'II',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'v',
#   'ii',
#   'III',
#   'ii',
#   'III',
#   'vi',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'vi',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'ii',
#   'v',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'v',
#   '$\\flat$VII',
#   'ii',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'v',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'ii',
#   'v',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'v',
#   '$\\flat$VII',
#   'ii',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'v',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'iii',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'i',
#   'II',
#   'v',
#   'IV',
#   'I',
#   'IV',
#   'iii',
#   'I',
#   'vi',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   '$\\flat$VII',
#   'ii',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'V',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'V',
#   'iii',
#   'I'],
#  ['i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['vi',
#   'IV',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'III',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'VI',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'vii',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'vii',
#   'I',
#   'V',
#   'II',
#   'V',
#   'vi',
#   'V',
#   'I',
#   '$\\flat$VII',
#   'ii',
#   'VI',
#   'v',
#   'VI',
#   'I',
#   'ii',
#   'V',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'III',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'VI',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'iii',
#   'III',
#   'IV',
#   'V',
#   'II',
#   'I',
#   'vi',
#   'ii',
#   'iii',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'iii',
#   'ii',
#   'VI',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$ii',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['iv',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$II',
#   'i',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'I',
#   'i',
#   '$\\flat$vii',
#   'iv',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iii',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'ii',
#   'VI',
#   'V',
#   'II',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'ii',
#   'I'],
#  ['I',
#   'iv',
#   'i',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$iii',
#   'IV',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$iii',
#   'IV',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'v',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\flat$vii',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'I',
#   'iv',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'iv',
#   'I'],
#  ['vi',
#   'V',
#   'I',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'VI',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'v',
#   'V',
#   'iii',
#   'vi',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'III',
#   'vi',
#   'IV',
#   'I',
#   'iii',
#   'V',
#   'ii',
#   'vi',
#   'IV',
#   'ii',
#   'iii',
#   'vii',
#   'II',
#   'V',
#   'vii',
#   'V',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'iii',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'iii',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vii',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'vi',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'IV',
#   'ii',
#   'iii',
#   'I',
#   'ii',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   'II',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'v',
#   'II',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'iv',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$III',
#   'iv',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'V',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'II',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   'III',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\sharp$IV',
#   '$\\flat$II',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$ii',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   'III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   '$\\flat$ii',
#   '$\\flat$iii',
#   'VII',
#   '$\\flat$ii',
#   'III',
#   'VII',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$VI'],
#  ['$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$II',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$II',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'VII',
#   '$\\flat$II',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$vii',
#   'VII',
#   '$\\flat$iii',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   'III',
#   'VII',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'II',
#   'V',
#   'III',
#   'vi',
#   'IV',
#   'V',
#   'II',
#   'V',
#   'III',
#   'I',
#   'III',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'iii',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'iii',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'IV',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'IV',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'IV',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'V',
#   'I',
#   'v',
#   'II',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'iii',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'vi',
#   'IV',
#   'vi',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'iii',
#   'II',
#   'V',
#   'II',
#   'V',
#   'ii',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'i',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'III',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'III',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'III',
#   'vi',
#   'VI',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'V',
#   'I',
#   'II',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'II',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   'III',
#   '$\\sharp$IV',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$II',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$vii',
#   'III',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'II',
#   'V',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'iii',
#   'ii',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'IV',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'IV',
#   'iii',
#   'IV',
#   'ii',
#   'iii',
#   'I',
#   'IV',
#   'iii',
#   'vi',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'IV',
#   'iii',
#   'IV',
#   'ii',
#   'iii',
#   'I',
#   'IV',
#   'iii',
#   'vi',
#   'V',
#   'ii',
#   'I',
#   'IV',
#   'ii',
#   'vi',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'iii',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'vi',
#   'III',
#   'VI',
#   'ii',
#   'vi',
#   'ii',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'III',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'III',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'IV',
#   'V',
#   'i',
#   'V',
#   'i',
#   'v',
#   '$\\flat$III',
#   'ii',
#   'IV',
#   '$\\flat$VII',
#   'II',
#   '$\\flat$III',
#   'II',
#   'V',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'i',
#   'v',
#   'ii',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'II',
#   'i',
#   'V',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   'i',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'IV',
#   'i',
#   'iv',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'I',
#   'i',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$III',
#   '$\\flat$iii',
#   'VII',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'iv',
#   'i',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$iii',
#   'IV',
#   'iv',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$II',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'iv',
#   'I'],
#  ['i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'II',
#   'v',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'II',
#   'v',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'i',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   'v',
#   'iv',
#   'II',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'i',
#   'V'],
#  ['$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$iii',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$II',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'vi',
#   'I',
#   'iii',
#   'ii',
#   'iii',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'iii',
#   'ii',
#   'iii',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'III',
#   'vii',
#   'V',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   '$\\flat$VII',
#   'VI',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'ii',
#   'IV',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'IV',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   'I',
#   '$\\flat$II',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['I',
#   'vi',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'II',
#   'V',
#   'vi',
#   'ii',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'V',
#   'IV',
#   'V',
#   'I'],
#  ['$\\flat$VII',
#   'v',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'v',
#   'i',
#   'v',
#   'iv',
#   '$\\flat$VII',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$II',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'v',
#   'i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$II',
#   'iv',
#   '$\\flat$II',
#   'I',
#   'iv',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$iii',
#   'III',
#   '$\\flat$ii',
#   'VII',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['vi',
#   'ii',
#   'V',
#   'iii',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'ii',
#   'V',
#   'iii',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VII',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'i',
#   'ii',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   'IV',
#   'ii',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'I'],
#  ['I',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'IV',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'III',
#   'vi',
#   'II',
#   'vi',
#   'IV',
#   'VII',
#   'III',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'iii',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'iii',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'VI',
#   'v',
#   'VI',
#   'ii',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'ii',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'I',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   'V'],
#  ['I',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'v',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'v',
#   'vi',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'IV',
#   'II',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'ii',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VII',
#   'IV',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'v',
#   'VI',
#   'IV',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'vi',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'iv',
#   'V',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   'iv',
#   'I'],
#  ['i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i'],
#  ['I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'ii',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'iv',
#   'i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'iv',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   'i',
#   'IV',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\sharp$IV',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   'i',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   '$\\flat$III',
#   '$\\flat$vii',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'v',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   'iv',
#   'IV',
#   '$\\flat$VI',
#   '$\\flat$III',
#   'i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'I',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'iv',
#   '$\\flat$III',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   'i',
#   'ii',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$vii',
#   '$\\flat$iii',
#   '$\\flat$vii',
#   'iv',
#   'I'],
#  ['i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'IV',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'i',
#   'v',
#   'II',
#   'ii',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   'I',
#   'iv',
#   'I',
#   'v',
#   'II',
#   'v',
#   'V',
#   'i',
#   'V',
#   'v',
#   'ii',
#   'i',
#   'II',
#   'v',
#   'ii',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'v',
#   'i',
#   'v',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   'ii',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   '$\\flat$VI',
#   'V',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   'II',
#   'v',
#   'II',
#   'V',
#   'i',
#   'IV',
#   'i',
#   'V',
#   'i',
#   'v',
#   'II',
#   'v',
#   'II',
#   'V',
#   'i',
#   'IV',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'I',
#   'iv',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'ii',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'ii',
# ...
#   'V',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'IV',
#   '$\\flat$VII',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'ii',
#   'IV',
#   'I',
#   'VI',
#   'ii',
#   'VI',
#   'ii',
#   'I',
#   'ii',
#   'IV',
#   'I',
#   'VI',
#   'ii',
#   'VI',
#   'ii',
#   'III',
#   'vi',
#   'ii',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'vi',
#   '$\\flat$VII',
#   'IV',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'vi',
#   '$\\flat$VII',
#   'IV',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'V',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'II',
#   'I',
#   'II',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'vi',
#   'IV',
#   'V',
#   'ii',
#   'VI',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   '$\\flat$VII',
#   'VI',
#   'ii',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   'VII',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$III',
#   '$\\flat$iii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   'v',
#   'II',
#   'v',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'V',
#   'i',
#   'ii',
#   'i',
#   'iv',
#   'V',
#   'iv',
#   'v',
#   '$\\flat$VII',
#   'i',
#   'I',
#   'ii',
#   'V',
#   'i',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'II',
#   'v',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'IV',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'II',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V'],
#  ['I',
#   'vi',
#   'iii',
#   'IV',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I'],
#  ['I',
#   'vi',
#   'v',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'iii',
#   'II',
#   'V',
#   'II',
#   'I',
#   'vi',
#   'v',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'I',
#   'iii',
#   'II',
#   'V',
#   'II',
#   'I',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'I',
#   'II',
#   'I',
#   'IV',
#   'vi',
#   'IV',
#   'V',
#   'ii',
#   'VI',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'ii',
#   'V'],
#  ['i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'i',
#   'V',
#   'i',
#   'IV',
#   'ii',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'i'],
#  ['I',
#   'ii',
#   'iii',
#   'vi',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'iv',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'iii',
#   'vi',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'iv',
#   'I',
#   'V',
#   'I',
#   'VI',
#   'II',
#   'vi',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$III',
#   'i',
#   'I',
#   'II',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'I',
#   'i',
#   '$\\flat$III',
#   'i',
#   'I',
#   'II',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'I',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'V',
#   '$\\flat$VI',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'v',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'v',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'iv',
#   '$\\flat$VII',
#   'v',
#   '$\\flat$III',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i'],
#  ['vi',
#   'IV',
#   'I',
#   'IV',
#   'II',
#   'v',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'i',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'ii',
#   'V',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'iii',
#   'IV',
#   'III',
#   'vi',
#   'ii',
#   'iii',
#   'ii',
#   'vi',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'ii',
#   'IV',
#   '$\\flat$VII',
#   'ii',
#   'VI',
#   'ii',
#   'VI',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'iii',
#   'I'],
#  ['I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'ii',
#   'iii',
#   'V',
#   'I',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'ii',
#   'vi',
#   'IV',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'V',
#   'iii',
#   'V',
#   'vi',
#   'iii',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['$\\flat$II',
#   '$\\flat$vii',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'I',
#   'iv',
#   '$\\flat$II',
#   'iv',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'iv',
#   'I'],
#  ['i',
#   'iv',
#   'V',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'v',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   '$\\flat$VI',
#   'v',
#   'I',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['I',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'I',
#   'IV',
#   'V',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'II',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'II',
#   'V',
#   'iii',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I'],
#  ['I',
#   'ii',
#   'V',
#   'I',
#   'V',
#   'I',
#   'II',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'iii',
#   'ii',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'ii',
#   'vi',
#   'V',
#   'I'],
#  ['$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   'III',
#   'VII',
#   'III',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$III',
#   'III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   '$\\flat$vii',
#   '$\\sharp$IV',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$iii',
#   'III',
#   '$\\flat$ii',
#   'VII',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$VI'],
#  ['IV',
#   'iii',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'iii',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'vi',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'II',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'vi',
#   'I',
#   'vi',
#   'ii',
#   'vi',
#   'III',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'iii',
#   'vi',
#   'I',
#   'V',
#   'II',
#   'V',
#   'I',
#   'V',
#   'I',
#   'ii',
#   'vi',
#   'I',
#   'ii',
#   'V',
#   'I'],
#  ['I',
#   'iv',
#   'i',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   '$\\flat$vii',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'I',
#   'iv',
#   'i',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   '$\\flat$vii',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'I',
#   'i',
#   '$\\flat$II',
#   'iv',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$vii',
#   'iv',
#   'I',
#   'iv',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$vii',
#   'I',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'IV',
#   '$\\flat$vii',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   'iv',
#   'I',
#   '$\\flat$II',
#   '$\\flat$VI',
#   '$\\flat$III',
#   '$\\flat$vii',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$II',
#   'iv',
#   'I'],
#  ['I',
#   'IV',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'ii',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'ii',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'ii',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'V',
#   'IV',
#   'ii',
#   '$\\flat$VII',
#   'ii',
#   'V',
#   'I',
#   '$\\flat$VII',
#   'ii',
#   'vi',
#   'ii',
#   'III',
#   'vi',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'vi',
#   'iii',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'I',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'I',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'iv',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'v',
#   'II',
#   'i',
#   'IV',
#   'i',
#   'vii',
#   'II',
#   'V',
#   'I'],
#  ['IV',
#   'v',
#   'IV',
#   'I',
#   'VI',
#   'ii',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'v',
#   'II',
#   'V',
#   'I',
#   'IV',
#   '$\\flat$VII',
#   'IV',
#   'I',
#   'V',
#   'iii',
#   'ii',
#   'I',
#   'V',
#   'I'],
#  ['i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   '$\\flat$VI',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'iv',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'V',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   'i',
#   'v',
#   'iv',
#   'I'],
#  ['VII',
#   'III',
#   'VII',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$vii',
#   'III',
#   '$\\flat$III',
#   'VII',
#   'III',
#   'VII',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\flat$ii',
#   '$\\flat$vii',
#   'III',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\sharp$IV',
#   'III',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$iii',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   'VII',
#   '$\\flat$vi',
#   'III',
#   '$\\flat$III'],
#  ['i',
#   'V',
#   '$\\flat$VI',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'V',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'I',
#   'iv',
#   'V',
#   'i'],
#  ['I',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'III',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'III',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'vi',
#   'VI',
#   'ii',
#   'vi',
#   'V',
#   'I',
#   'vi',
#   'V',
#   'I',
#   'iii',
#   'I',
#   'ii',
#   'V',
#   'I'],
#  ['I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'iii',
#   'ii',
#   'iii',
#   'I',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'iii',
#   'ii',
#   'iii',
#   'I',
#   'III',
#   'vi',
#   'I',
#   'V',
#   'I',
#   'iii',
#   'I',
#   'vi',
#   'I',
#   'ii',
#   'III',
#   'vi',
#   'IV',
#   'ii',
#   'I'],
#  ['I',
#   'IV',
#   'I',
#   'III',
#   'vi',
#   'IV',
#   'I',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'ii',
#   'V',
#   'III',
#   'vi',
#   'V',
#   'I',
#   'ii',
#   'VI',
#   'vi',
#   'IV',
#   'I',
#   'iii',
#   'V',
#   'I',
#   'ii',
#   'I',
#   'IV',
#   'I'],
#  ['$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   'III',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$II',
#   '$\\flat$VII',
#   '$\\flat$iii',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   'III',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$iii',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   '$\\sharp$IV',
#   '$\\flat$II',
#   '$\\sharp$IV',
#   '$\\flat$III',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$vi',
#   '$\\flat$ii',
#   '$\\flat$VII',
#   '$\\flat$iii',
#   'VII',
#   '$\\flat$vi',
#   '$\\flat$VI'],
#  ['I',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'IV',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'ii',
#   'VI',
#   'ii',
#   'I',
#   'IV',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'IV',
#   'v',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'I'],
#  ['I',
#   'IV',
#   'ii',
#   'I',
#   'iii',
#   'I',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'ii',
#   'V',
#   'III',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'ii',
#   'IV',
#   'I',
#   'vi',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'iii',
#   'vi',
#   'I',
#   'V',
#   'vi',
#   'IV',
#   'ii',
#   'I',
#   'IV',
#   'iii',
#   'V',
#   'I'],
#  ['III',
#   'VI',
#   'III',
#   '$\\sharp$iv',
#   'III',
#   'VII',
#   'III',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   'III',
#   'VI',
#   'III',
#   '$\\sharp$iv',
#   'III',
#   'VII',
#   'III',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\flat$VI',
#   '$\\flat$ii',
#   '$\\sharp$iv',
#   'III',
#   'VI',
#   'III',
#   'VI',
#   '$\\sharp$iv',
#   '$\\flat$II',
#   'VII',
#   '$\\flat$ii',
#   'VII',
#   '$\\sharp$IV',
#   'VII',
#   'III',
#   '$\\sharp$iv',
#   'III',
#   'VII',
#   '$\\flat$ii',
#   '$\\flat$VI'],
#  ['I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'vi',
#   'ii',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'vi',
#   'I',
#   'V',
#   'vi',
#   'ii',
#   'IV',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'III',
#   'vi',
#   'ii',
#   'V',
#   'I',
#   'vi',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'vi',
#   'II',
#   'vi',
#   'V',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'vi',
#   'IV',
#   '$\\flat$VII',
#   'ii',
#   'I',
#   'IV',
#   'I',
#   'V',
#   'I',
#   'IV',
#   'V',
#   'I',
#   'V',
#   'vi',
#   'V',
#   'I'],
#  ['i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'iv',
#   'i',
#   'V',
#   'i',
#   'IV',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'IV',
#   '$\\flat$VII',
#   'i',
#   '$\\flat$VI',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VI',
#   'iv',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'iv',
#   'i',
#   'iv',
#   'i',
#   'iv',
#   'V',
#   'i',
#   'V',
#   'i',
#   'V',
#   'i',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'IV',
#   'ii',
#   'v',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'v',
#   '$\\flat$VII',
#   '$\\flat$III',
#   'i',
#   'V',
#   'i',
#   'V',
#   'I'],
#  ['i',
#   'v',
#   '$\\flat$III',
#   'V',
#   '$\\flat$VI',
#   'ii',
#   'i',
#   'V',
#   'i',
#   'v',
#   '$\\flat$III',
#   'V',
#   '$\\flat$VI',
#   'ii',
#   'i',
#   'V',
#   'i',
#   'iv',
#   'IV',
#   'i',
#   '$\\flat$III',
#   'iv',
#   'V',
#   'i',
#   '$\\flat$VII',
#   'I',
#   'vi',
#   'II',
#   '$\\flat$III',
#   'II',
#   'v',
#   '$\\flat$VII',
#   '$\\flat$III',
#   '$\\flat$VII',
#   'IV',
#   'i',
#   '$\\flat$VI',
#   'V',
#   'I']]
