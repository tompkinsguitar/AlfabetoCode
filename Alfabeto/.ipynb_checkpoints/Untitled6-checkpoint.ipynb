# %%
import ipyparallel as ipp
from sklearn.externals import joblib

# %%
rc = ipp.Client()
dview = rc[:]

dview.execute('import numpy as np')
dview.execute('import time')
dview.execute('from sklearn.externals import joblib')
dview.execute('from scipy.spatial.distance import cdist')
dview.execute('import alfabeto_data.dissertation_images as di')
# Out:
# <AsyncResult: execute>

# %%
all_silhouette_ = {}
thenumber_ = 0
for corpus_ in ['alfabeto_continuo', 'bach', 'palestrina']:
    for mode_ in ['major', 'minor']:
        for mc_ in range(5):
            all_silhouette_[thenumber_] = {'corpus': corpus_, 'mode': mode_, 'mc': mc_}
            thenumber_ += 1

# %%
@dview.parallel(block=True)
def silhouette_hmm(silhouette_number):
    all_silhouette = {}
    thenumber = 0
    for corpus in ['alfabeto_continuo', 'bach', 'palestrina']:
        for mode in ['major', 'minor']:
            for mcc in range(5):
                all_silhouette[thenumber] = {'corpus': corpus, 'mode': mode, 'mc': mcc}
                thenumber += 1
    corpus_name = all_silhouette[silhouette_number]['corpus']
    mode_name = all_silhouette[silhouette_number]['mode']
    mc = all_silhouette[silhouette_number]['mc']
    K_range = 15
    flipped_data = {}
    for K in range(2, K_range+1):
        all_data = []
        all_labels = []
        l_number = joblib.load('/home/daniel/Desktop/hmm_mc/%s/%s/%s/%s/0.pkl' % (corpus_name, mode_name, K, mc))['test'][0]
        l_numeral = joblib.load('/home/daniel/Desktop/hmm_mc/%s/%s/%s/%s/0.pkl' % (corpus_name, mode_name, K, mc))['train'][2]
        for l in l_number:
            if l[0] < len(l_numeral):
                all_labels.append(l_numeral[l[0]])
            else:
                all_labels.append('o')
        #             print('one didn\'t fit...')
        for x in range(500):
            temp_data = []
            print(x)
            c = joblib.load('/home/daniel/Desktop/hmm_mc/%s/%s/%s/%s/%s.pkl' % (corpus_name, mode_name, K, mc, x))['decode']
            print('decoded')
            for xx in c[1]:
                temp_data.append(xx)
            all_data.append(temp_data)
        numpied = np.swapaxes(np.array(all_data), 0, 1)
    #     print(numpied.shape)
        st = time.time()
        DIST = cdist(numpied, numpied, 'hamming')
    #     DIST = (cdist(numpied, numpied, 'hamming')*len(l_number))**2 #Quinn/White
        st2 = time.time()
        flipped_data[K] = di.k_means_simple(DIST, K, all_labels)
    #     print_labels = ['$'+x+'$' for x in all_labels]
    #     di.k_means_data(DIST, K, print_labels, '/home/daniel/Desktop/hmmkmeans/%s_%s.pdf' % (corpus, K))
    #     print('kmeans took', time.time()-st2)
        print(K, '-->', flipped_data[K])
    return {(corpus_name, mode_name, mc): flipped_data}

# %%
j = silhouette_hmm.map([mc for mc in range(len(all_silhouette_))])
joblib.dump(j, '/home/daniel/Desktop/silhouette_data.pkl', compress=True)
# Out:
# ['/home/daniel/Desktop/silhouette_data.pkl']

# %%
j
# Out:
# [{('alfabeto_continuo',
#    'major',
#    0): {2: {'completeness': 0.83544563202798272,
#     'silhouette': 0.96949812934582758}, 3: {'completeness': 0.83600349226648563,
#     'silhouette': 0.98173518931147485}, 4: {'completeness': 0.84891316640904324,
#     'silhouette': 0.9054803449345209}, 5: {'completeness': 0.7468733035325118,
#     'silhouette': 0.71086716309217024}, 6: {'completeness': 0.83521020007495561,
#     'silhouette': 0.64848350668140686}, 7: {'completeness': 0.7059715894053098,
#     'silhouette': 0.60426052216769377}, 8: {'completeness': 0.86618678687831752,
#     'silhouette': 0.66081271079640858}, 9: {'completeness': 0.90853037032212647,
#     'silhouette': 0.73493594782065774}, 10: {'completeness': 0.92371516950301358,
#     'silhouette': 0.78068628062951984}, 11: {'completeness': 0.91393387522635927,
#     'silhouette': 0.77755966098620555}, 12: {'completeness': 0.87476768298213248,
#     'silhouette': 0.77269527397872606}, 13: {'completeness': 0.7218262968312541,
#     'silhouette': 0.63488344257589957}, 14: {'completeness': 0.84430850553186554,
#     'silhouette': 0.76013184039323722}, 15: {'completeness': 0.83143700043795388,
#     'silhouette': 0.76507455449246675}}},
#  {('alfabeto_continuo',
#    'major',
#    1): {2: {'completeness': 0.88941694770359858,
#     'silhouette': 0.90273781070956771}, 3: {'completeness': 0.83685916533443727,
#     'silhouette': 0.98868896946185858}, 4: {'completeness': 0.84911067829702058,
#     'silhouette': 0.91474027676348879}, 5: {'completeness': 0.76715450157036924,
#     'silhouette': 0.69859320658833157}, 6: {'completeness': 0.83017463614251086,
#     'silhouette': 0.64335944877678541}, 7: {'completeness': 0.72856556451462851,
#     'silhouette': 0.5690500405744493}, 8: {'completeness': 0.87350388180841676,
#     'silhouette': 0.67454543969905523}, 9: {'completeness': 0.90661366265896559,
#     'silhouette': 0.74126730687317144}, 10: {'completeness': 0.91910441717654112,
#     'silhouette': 0.76775523431850856}, 11: {'completeness': 0.76757394170480142,
#     'silhouette': 0.69961665336682344}, 12: {'completeness': 0.77468808399646816,
#     'silhouette': 0.6639607645801372}, 13: {'completeness': 0.86522503477222346,
#     'silhouette': 0.76682961058809807}, 14: {'completeness': 0.8465128715776522,
#     'silhouette': 0.75533994157550211}, 15: {'completeness': 0.82450639487248345,
#     'silhouette': 0.7482071712386934}}},
#  {('alfabeto_continuo',
#    'major',
#    2): {2: {'completeness': 0.85230465237316544,
#     'silhouette': 0.92200197395463268}, 3: {'completeness': 0.65415629764516647,
#     'silhouette': 0.86071216647441506}, 4: {'completeness': 0.82587720797187036,
#     'silhouette': 0.87780016433864527}, 5: {'completeness': 0.76334166969845663,
#     'silhouette': 0.72154046177739661}, 6: {'completeness': 0.79001431399602162,
#     'silhouette': 0.61278267638342698}, 7: {'completeness': 0.75024072323973157,
#     'silhouette': 0.63705755106233686}, 8: {'completeness': 0.90456649587770099,
#     'silhouette': 0.68519401458949425}, 9: {'completeness': 0.91391519840690782,
#     'silhouette': 0.74142255825119252}, 10: {'completeness': 0.93186598714990898,
#     'silhouette': 0.82205193886281591}, 11: {'completeness': 0.90435240292641728,
#     'silhouette': 0.79483310957403286}, 12: {'completeness': 0.85512542569327998,
#     'silhouette': 0.75712636329895544}, 13: {'completeness': 0.88637580068424782,
#     'silhouette': 0.77288560117857674}, 14: {'completeness': 0.84341181623850847,
#     'silhouette': 0.7631383208347543}, 15: {'completeness': 0.83079570923642176,
#     'silhouette': 0.75709544882648383}}},
#  {('alfabeto_continuo',
#    'major',
#    3): {2: {'completeness': 0.89337813889365569,
#     'silhouette': 0.89687225841356732}, 3: {'completeness': 0.85201974219889898,
#     'silhouette': 0.98250543792356215}, 4: {'completeness': 0.85600937593824522,
#     'silhouette': 0.89887975063402159}, 5: {'completeness': 0.77604003776017172,
#     'silhouette': 0.70601252716338148}, 6: {'completeness': 0.78057110281578224,
#     'silhouette': 0.62456993230880831}, 7: {'completeness': 0.87437939825204658,
#     'silhouette': 0.60731479242863584}, 8: {'completeness': 0.87722643589577987,
#     'silhouette': 0.67710659970867448}, 9: {'completeness': 0.91883934739976636,
#     'silhouette': 0.72449025342155093}, 10: {'completeness': 0.92535041863411216,
#     'silhouette': 0.78008106841068736}, 11: {'completeness': 0.90867403608427566,
#     'silhouette': 0.78395060761022139}, 12: {'completeness': 0.87438818308381339,
#     'silhouette': 0.75739158819860442}, 13: {'completeness': 0.838652929905497,
#     'silhouette': 0.72209796699120399}, 14: {'completeness': 0.85442740669447836,
#     'silhouette': 0.74262392205147654}, 15: {'completeness': 0.82653867912550416,
#     'silhouette': 0.76547953343524233}}},
#  {('alfabeto_continuo',
#    'major',
#    4): {2: {'completeness': 0.91108135467880003,
#     'silhouette': 0.88115978147161}, 3: {'completeness': 0.85501132168910976,
#     'silhouette': 0.9868927959474918}, 4: {'completeness': 0.85707491576666117,
#     'silhouette': 0.91702826619265654}, 5: {'completeness': 0.76816767042480849,
#     'silhouette': 0.69545755641762519}, 6: {'completeness': 0.81670980678449823,
#     'silhouette': 0.64159994743138837}, 7: {'completeness': 0.83573731630394699,
#     'silhouette': 0.57945206693250972}, 8: {'completeness': 0.716157018707967,
#     'silhouette': 0.6128940020293544}, 9: {'completeness': 0.89946812156764377,
#     'silhouette': 0.72130575378377448}, 10: {'completeness': 0.78442619377211875,
#     'silhouette': 0.68031761224025866}, 11: {'completeness': 0.91187396248261288,
#     'silhouette': 0.77834599197915588}, 12: {'completeness': 0.90672158330802066,
#     'silhouette': 0.78211382846924959}, 13: {'completeness': 0.76721086813237382,
#     'silhouette': 0.67319384657743431}, 14: {'completeness': 0.84527438172557168,
#     'silhouette': 0.76797037448430794}, 15: {'completeness': 0.82114966279342561,
#     'silhouette': 0.7762925097850073}}},
#  {('alfabeto_continuo',
#    'minor',
#    0): {2: {'completeness': 0.80617043134990984,
#     'silhouette': 0.79212945423772363}, 3: {'completeness': 0.82045035812294265,
#     'silhouette': 0.93775661657672194}, 4: {'completeness': 0.73877636600943419,
#     'silhouette': 0.73224512336917502}, 5: {'completeness': 0.80958628703137969,
#     'silhouette': 0.6941607535166282}, 6: {'completeness': 0.90011999315137781,
#     'silhouette': 0.66692711721801956}, 7: {'completeness': 0.66582444959916409,
#     'silhouette': 0.72393039237861911}, 8: {'completeness': 0.79255325965334467,
#     'silhouette': 0.5653781862235534}, 9: {'completeness': 0.8520638817937819,
#     'silhouette': 0.71756580788748547}, 10: {'completeness': 0.88639995335184396,
#     'silhouette': 0.73857595204027671}, 11: {'completeness': 0.76245820549299592,
#     'silhouette': 0.62249296155445055}, 12: {'completeness': 0.75614512099628728,
#     'silhouette': 0.63614533878025115}, 13: {'completeness': 0.84942676064550338,
#     'silhouette': 0.71009042102195608}, 14: {'completeness': 0.85701491992361234,
#     'silhouette': 0.69091927452162905}, 15: {'completeness': 0.85385037669325714,
#     'silhouette': 0.71579408393086152}}},
#  {('alfabeto_continuo',
#    'minor',
#    1): {2: {'completeness': 0.92823027939362523,
#     'silhouette': 0.73669101034780504}, 3: {'completeness': 0.80946959567160326,
#     'silhouette': 0.96274720829670524}, 4: {'completeness': 0.42370110633337454,
#     'silhouette': 0.7635129421034208}, 5: {'completeness': 0.64840374482244956,
#     'silhouette': 0.6252278614596869}, 6: {'completeness': 0.52695143438033942,
#     'silhouette': 0.69056685891283764}, 7: {'completeness': 0.83253631724344779,
#     'silhouette': 0.66678665498615208}, 8: {'completeness': 0.92755271449623833,
#     'silhouette': 0.67613776583139718}, 9: {'completeness': 0.92091588957317216,
#     'silhouette': 0.71740602686416899}, 10: {'completeness': 0.89768209406003463,
#     'silhouette': 0.72798409038713607}, 11: {'completeness': 0.7489006509399998,
#     'silhouette': 0.75613785524825039}, 12: {'completeness': 0.78777980515338741,
#     'silhouette': 0.58292846248064545}, 13: {'completeness': 0.85654881655534731,
#     'silhouette': 0.71123098223491499}, 14: {'completeness': 0.85146249617372294,
#     'silhouette': 0.68624867961922364}, 15: {'completeness': 0.84446850234194026,
#     'silhouette': 0.6846262934045626}}},
#  {('alfabeto_continuo',
#    'minor',
#    2): {2: {'completeness': 0.50259133597079464,
#     'silhouette': 0.70304027671543945}, 3: {'completeness': 0.74327160015502503,
#     'silhouette': 0.93770673573144636}, 4: {'completeness': 0.82998022380626557,
#     'silhouette': 0.72389573883918945}, 5: {'completeness': 0.78126883207018394,
#     'silhouette': 0.68204659894806319}, 6: {'completeness': 0.62608602308166039,
#     'silhouette': 0.67751738812580775}, 7: {'completeness': 0.812919299250073,
#     'silhouette': 0.6821953272282264}, 8: {'completeness': 0.84663190817518319,
#     'silhouette': 0.76924193080566128}, 9: {'completeness': 0.7541043406762179,
#     'silhouette': 0.62089343816623099}, 10: {'completeness': 0.90296600148431416,
#     'silhouette': 0.76152435548833719}, 11: {'completeness': 0.89159717873334909,
#     'silhouette': 0.73370507567011822}, 12: {'completeness': 0.73879843586297977,
#     'silhouette': 0.75561113802126689}, 13: {'completeness': 0.80091382452119675,
#     'silhouette': 0.60612095398283417}, 14: {'completeness': 0.84600302634977931,
#     'silhouette': 0.70012189296752447}, 15: {'completeness': 0.67960173610641395,
#     'silhouette': 0.66443328687314851}}},
#  {('alfabeto_continuo',
#    'minor',
#    3): {2: {'completeness': 0.80429895200195567,
#     'silhouette': 0.74157091510106821}, 3: {'completeness': 0.85779687638207858,
#     'silhouette': 0.9498589269551202}, 4: {'completeness': 0.62539188487171937,
#     'silhouette': 0.61203797127483051}, 5: {'completeness': 0.78096624123917724,
#     'silhouette': 0.70124553631929398}, 6: {'completeness': 0.87287312265106376,
#     'silhouette': 0.63087057903348787}, 7: {'completeness': 0.90010333146368393,
#     'silhouette': 0.6699324760049401}, 8: {'completeness': 0.89408737955405748,
#     'silhouette': 0.70933445468679968}, 9: {'completeness': 0.86954372920326783,
#     'silhouette': 0.7096565608193488}, 10: {'completeness': 0.90997924682576115,
#     'silhouette': 0.75535082582091506}, 11: {'completeness': 0.87177347690858153,
#     'silhouette': 0.74837969856379816}, 12: {'completeness': 0.85972541712588746,
#     'silhouette': 0.74261536762904357}, 13: {'completeness': 0.84074263841888397,
#     'silhouette': 0.71474925671762524}, 14: {'completeness': 0.86385683596639762,
#     'silhouette': 0.68681260872386551}, 15: {'completeness': 0.84660027382367786,
#     'silhouette': 0.6787366522885091}}},
#  {('alfabeto_continuo',
#    'minor',
#    4): {2: {'completeness': 0.79752259077028598,
#     'silhouette': 0.72424505697441033}, 3: {'completeness': 0.64352503681235629,
#     'silhouette': 0.84361262340058341}, 4: {'completeness': 0.61043493521658421,
#     'silhouette': 0.61978225687544097}, 5: {'completeness': 0.78219862200001811,
#     'silhouette': 0.6850856636588486}, 6: {'completeness': 0.87790441240128225,
#     'silhouette': 0.65435580264425164}, 7: {'completeness': 0.6602340203827195,
#     'silhouette': 0.73990133396354807}, 8: {'completeness': 0.84153524179181061,
#     'silhouette': 0.71587576396127472}, 9: {'completeness': 0.83134322879589517,
#     'silhouette': 0.74497266872490098}, 10: {'completeness': 0.79826738469072478,
#     'silhouette': 0.75205663164803982}, 11: {'completeness': 0.89980684618059703,
#     'silhouette': 0.7647705951858742}, 12: {'completeness': 0.86612554583533641,
#     'silhouette': 0.7476187381395174}, 13: {'completeness': 0.65921730960497049,
#     'silhouette': 0.73463652933110191}, 14: {'completeness': 0.65329269842463977,
#     'silhouette': 0.73684126985623577}, 15: {'completeness': 0.86598475091846627,
#     'silhouette': 0.68173100067668246}}},
#  {('bach',
#    'major',
#    0): {2: {'completeness': 0.68165658931430551,
#     'silhouette': 0.8304627285609224}, 3: {'completeness': 0.50776673020173779,
#     'silhouette': 0.8832629550696306}, 4: {'completeness': 0.6202001882493331,
#     'silhouette': 0.72457667641989409}, 5: {'completeness': 0.50427985988524171,
#     'silhouette': 0.73767242437332037}, 6: {'completeness': 0.6471043310410467,
#     'silhouette': 0.52878425706285048}, 7: {'completeness': 0.64311112892406341,
#     'silhouette': 0.50494850139387237}, 8: {'completeness': 0.69829577075222049,
#     'silhouette': 0.50853912987409988}, 9: {'completeness': 0.62571871106313615,
#     'silhouette': 0.49691282634475153}, 10: {'completeness': 0.78189150953918907,
#     'silhouette': 0.56085761147683766}, 11: {'completeness': 0.76614130910250955,
#     'silhouette': 0.60744485083844268}, 12: {'completeness': 0.8039948174388204,
#     'silhouette': 0.66256086829604011}, 13: {'completeness': 0.77129096631817951,
#     'silhouette': 0.6795581261409267}, 14: {'completeness': 0.68138819068683709,
#     'silhouette': 0.4953776135345706}, 15: {'completeness': 0.79096321328578933,
#     'silhouette': 0.71612401079913579}}},
#  {('bach',
#    'major',
#    1): {2: {'completeness': 0.70932800692415765,
#     'silhouette': 0.83199629060006342}, 3: {'completeness': 0.62275876165929789,
#     'silhouette': 0.91991713137471243}, 4: {'completeness': 0.58213165482843432,
#     'silhouette': 0.7152539856706045}, 5: {'completeness': 0.64924415546534842,
#     'silhouette': 0.79545323792425759}, 6: {'completeness': 0.665597218434414,
#     'silhouette': 0.59294139618463959}, 7: {'completeness': 0.67235654861511784,
#     'silhouette': 0.54823893716460426}, 8: {'completeness': 0.70236290494375864,
#     'silhouette': 0.54257379440624698}, 9: {'completeness': 0.75943955792662743,
#     'silhouette': 0.54242527768221716}, 10: {'completeness': 0.76939791562233939,
#     'silhouette': 0.58641217777832266}, 11: {'completeness': 0.76248824973110529,
#     'silhouette': 0.60197787520328583}, 12: {'completeness': 0.75302354402911797,
#     'silhouette': 0.61293891820440805}, 13: {'completeness': 0.78120153442076579,
#     'silhouette': 0.65081868376790708}, 14: {'completeness': 0.78801020159468282,
#     'silhouette': 0.71382796191316655}, 15: {'completeness': 0.78478984832098553,
#     'silhouette': 0.68867045336934396}}},
#  {('bach',
#    'major',
#    2): {2: {'completeness': 0.70048786736284396,
#     'silhouette': 0.82420243670341886}, 3: {'completeness': 0.6267043621772137,
#     'silhouette': 0.9497502621939703}, 4: {'completeness': 0.51809493155680075,
#     'silhouette': 0.60307216146233322}, 5: {'completeness': 0.56465830022768204,
#     'silhouette': 0.71304309166774826}, 6: {'completeness': 0.635689441390757,
#     'silhouette': 0.57046521167235376}, 7: {'completeness': 0.67984667873561733,
#     'silhouette': 0.56143142207421515}, 8: {'completeness': 0.68480191457008788,
#     'silhouette': 0.48933903166571968}, 9: {'completeness': 0.77250605222666069,
#     'silhouette': 0.56302118689651215}, 10: {'completeness': 0.77097019599450833,
#     'silhouette': 0.57917838771388552}, 11: {'completeness': 0.76027449920449819,
#     'silhouette': 0.59803869275489241}, 12: {'completeness': 0.64633330288833524,
#     'silhouette': 0.46357643224992529}, 13: {'completeness': 0.76885155586505416,
#     'silhouette': 0.63766698898989593}, 14: {'completeness': 0.7481780390088586,
#     'silhouette': 0.66946048383691836}, 15: {'completeness': 0.56929436951844137,
#     'silhouette': 0.45742006250939887}}},
#  {('bach',
#    'major',
#    3): {2: {'completeness': 0.75218378259171426,
#     'silhouette': 0.84743739075777091}, 3: {'completeness': 0.64652075281626586,
#     'silhouette': 0.93024068024703299}, 4: {'completeness': 0.58013703349689016,
#     'silhouette': 0.7118647872145234}, 5: {'completeness': 0.68782522250871636,
#     'silhouette': 0.77804550102533776}, 6: {'completeness': 0.65395988158606888,
#     'silhouette': 0.56442084295254402}, 7: {'completeness': 0.66701796654208356,
#     'silhouette': 0.53977528769072169}, 8: {'completeness': 0.64157905626535972,
#     'silhouette': 0.45422360270897039}, 9: {'completeness': 0.75135368978499772,
#     'silhouette': 0.53962350877510057}, 10: {'completeness': 0.78699463546178694,
#     'silhouette': 0.58897894717048094}, 11: {'completeness': 0.69758779968715301,
#     'silhouette': 0.475822739142642}, 12: {'completeness': 0.66499219656628172,
#     'silhouette': 0.47839857923237966}, 13: {'completeness': 0.61918521271761573,
#     'silhouette': 0.49433169046049852}, 14: {'completeness': 0.78722465281835674,
#     'silhouette': 0.70096120488275149}, 15: {'completeness': 0.7682012436469996,
#     'silhouette': 0.70486053711287489}}},
#  {('bach',
#    'major',
#    4): {2: {'completeness': 0.69835391005418423,
#     'silhouette': 0.81624522824681645}, 3: {'completeness': 0.6191299543630614,
#     'silhouette': 0.94152982061513557}, 4: {'completeness': 0.59607842838335856,
#     'silhouette': 0.69658270851667625}, 5: {'completeness': 0.67216636143760389,
#     'silhouette': 0.80464867471836865}, 6: {'completeness': 0.66534925674897571,
#     'silhouette': 0.61787445611649772}, 7: {'completeness': 0.65541468546471804,
#     'silhouette': 0.49826380604488824}, 8: {'completeness': 0.63412819124054565,
#     'silhouette': 0.51953384475460673}, 9: {'completeness': 0.74479574815472882,
#     'silhouette': 0.5531501279586456}, 10: {'completeness': 0.78062001187958985,
#     'silhouette': 0.59719747614865826}, 11: {'completeness': 0.68300224690859079,
#     'silhouette': 0.43633889194627712}, 12: {'completeness': 0.78012623307025897,
#     'silhouette': 0.63291711711922827}, 13: {'completeness': 0.60605991572142615,
#     'silhouette': 0.48109427356460965}, 14: {'completeness': 0.78064348179952203,
#     'silhouette': 0.69561439192008667}, 15: {'completeness': 0.53803259811075554,
#     'silhouette': 0.48279873373114396}}},
#  {('bach',
#    'minor',
#    0): {2: {'completeness': 0.61382928900551725,
#     'silhouette': 0.80490263328628564}, 3: {'completeness': 0.80542396031524011,
#     'silhouette': 0.97020611183592431}, 4: {'completeness': 0.69205035737853116,
#     'silhouette': 0.85625816621325201}, 5: {'completeness': 0.58942828919432011,
#     'silhouette': 0.54543743775477427}, 6: {'completeness': 0.73982366075063621,
#     'silhouette': 0.62839164393084623}, 7: {'completeness': 0.86579886196811451,
#     'silhouette': 0.5360015868067477}, 8: {'completeness': 0.81662138489704827,
#     'silhouette': 0.62818049126553488}, 9: {'completeness': 0.83389804078594942,
#     'silhouette': 0.57704361799302173}, 10: {'completeness': 0.82191011640551892,
#     'silhouette': 0.5979481620115018}, 11: {'completeness': 0.82092847369225341,
#     'silhouette': 0.6282360083075551}, 12: {'completeness': 0.82690997892585882,
#     'silhouette': 0.58330838637283156}, 13: {'completeness': 0.82741547369954049,
#     'silhouette': 0.59543107766405667}, 14: {'completeness': 0.85278522553361491,
#     'silhouette': 0.50675242035010326}, 15: {'completeness': 0.80077341231869958,
#     'silhouette': 0.51094338742919809}}},
#  {('bach',
#    'minor',
#    1): {2: {'completeness': 0.80205222047002278,
#     'silhouette': 0.85195590253557274}, 3: {'completeness': 0.73631305078377818,
#     'silhouette': 0.94277288406708037}, 4: {'completeness': 0.71259998570644567,
#     'silhouette': 0.84576690575018321}, 5: {'completeness': 0.67785503523380386,
#     'silhouette': 0.53704503794459435}, 6: {'completeness': 0.70343504176287819,
#     'silhouette': 0.61729958481650149}, 7: {'completeness': 0.78926929422364456,
#     'silhouette': 0.53610952213943586}, 8: {'completeness': 0.83610176935226721,
#     'silhouette': 0.59757906231792368}, 9: {'completeness': 0.83678767725101955,
#     'silhouette': 0.54074619083066722}, 10: {'completeness': 0.81611230246162347,
#     'silhouette': 0.63670060460426225}, 11: {'completeness': 0.80863356291613475,
#     'silhouette': 0.58139075688456676}, 12: {'completeness': 0.77316633485285979,
#     'silhouette': 0.47873792214390704}, 13: {'completeness': 0.82176733818868331,
#     'silhouette': 0.53427918755128911}, 14: {'completeness': 0.82677260230449379,
#     'silhouette': 0.55100979145454965}, 15: {'completeness': 0.83405121291925244,
#     'silhouette': 0.54485201300156283}}},
#  {('bach',
#    'minor',
#    2): {2: {'completeness': 0.7047354247436608,
#     'silhouette': 0.82609760179608671}, 3: {'completeness': 0.85861798342145479,
#     'silhouette': 0.94881930685404559}, 4: {'completeness': 0.69766568227038528,
#     'silhouette': 0.86991505679228376}, 5: {'completeness': 0.72211949904432227,
#     'silhouette': 0.73127744028002672}, 6: {'completeness': 0.72648866274251289,
#     'silhouette': 0.61123802817340012}, 7: {'completeness': 0.75267414728478843,
#     'silhouette': 0.54827632544244986}, 8: {'completeness': 0.8906215813922832,
#     'silhouette': 0.61500622569716135}, 9: {'completeness': 0.86483982108209512,
#     'silhouette': 0.58619838665987078}, 10: {'completeness': 0.80614328412024217,
#     'silhouette': 0.55903519282846481}, 11: {'completeness': 0.84429574393243212,
#     'silhouette': 0.57563728675354098}, 12: {'completeness': 0.82765857606353677,
#     'silhouette': 0.6306493555468824}, 13: {'completeness': 0.8600748995518831,
#     'silhouette': 0.57806375372219165}, 14: {'completeness': 0.79770343197050864,
#     'silhouette': 0.52122551703720832}, 15: {'completeness': 0.85275736595397722,
#     'silhouette': 0.55434772026986101}}},
#  {('bach',
#    'minor',
#    3): {2: {'completeness': 0.79543111546038181,
#     'silhouette': 0.79370725477532611}, 3: {'completeness': 0.84995042101945051,
#     'silhouette': 0.96545982489261717}, 4: {'completeness': 0.71166867815283708,
#     'silhouette': 0.8779650845645901}, 5: {'completeness': 0.75775206191228106,
#     'silhouette': 0.6837313914643105}, 6: {'completeness': 0.73086492736945363,
#     'silhouette': 0.60561116985487273}, 7: {'completeness': 0.7884075308195343,
#     'silhouette': 0.55384234401339583}, 8: {'completeness': 0.65800709786999811,
#     'silhouette': 0.50420785624654363}, 9: {'completeness': 0.79520223027326242,
#     'silhouette': 0.6005999421094993}, 10: {'completeness': 0.68697677046611072,
#     'silhouette': 0.66773392489444461}, 11: {'completeness': 0.84697946266691948,
#     'silhouette': 0.59541654939506206}, 12: {'completeness': 0.83466662196535013,
#     'silhouette': 0.56337454210770854}, 13: {'completeness': 0.86490800674799062,
#     'silhouette': 0.53375417097742217}, 14: {'completeness': 0.84464475411721973,
#     'silhouette': 0.55823416047465979}, 15: {'completeness': 0.84183612047436185,
#     'silhouette': 0.55069441174036293}}},
#  {('bach',
#    'minor',
#    4): {2: {'completeness': 0.68712174163062512,
#     'silhouette': 0.80041439684721083}, 3: {'completeness': 0.77226937729755507,
#     'silhouette': 0.96690469952048819}, 4: {'completeness': 0.6700538795601042,
#     'silhouette': 0.87065282267908428}, 5: {'completeness': 0.73000869041015848,
#     'silhouette': 0.78097563668347403}, 6: {'completeness': 0.71927678795024275,
#     'silhouette': 0.63174652762741079}, 7: {'completeness': 0.75553060831969499,
#     'silhouette': 0.55649383444208067}, 8: {'completeness': 0.81052283402828951,
#     'silhouette': 0.54077126366029826}, 9: {'completeness': 0.83995270259795773,
#     'silhouette': 0.62791013165163323}, 10: {'completeness': 0.77944102957593131,
#     'silhouette': 0.57359939892313816}, 11: {'completeness': 0.75090481314520197,
#     'silhouette': 0.48289781694054723}, 12: {'completeness': 0.79934585135859992,
#     'silhouette': 0.52639344927870957}, 13: {'completeness': 0.78038759243790423,
#     'silhouette': 0.48116089373371712}, 14: {'completeness': 0.79973032607934746,
#     'silhouette': 0.55461286610233473}, 15: {'completeness': 0.80963830719636742,
#     'silhouette': 0.52313184498911591}}},
#  {('palestrina',
#    'major',
#    0): {2: {'completeness': 0.70321879999090242,
#     'silhouette': 0.6878625364290476}, 3: {'completeness': 0.7525957495922756,
#     'silhouette': 0.54624817057885089}, 4: {'completeness': 0.70580537033516222,
#     'silhouette': 0.65957886651232811}, 5: {'completeness': 0.70539663909356531,
#     'silhouette': 0.6324274205806758}, 6: {'completeness': 0.692663745165355,
#     'silhouette': 0.62188069201534246}, 7: {'completeness': 0.69808480661195349,
#     'silhouette': 0.55486740896745712}, 8: {'completeness': 0.7659151661481971,
#     'silhouette': 0.69959943070470132}, 9: {'completeness': 0.71017800153213084,
#     'silhouette': 0.61659074172715533}, 10: {'completeness': 0.44499480656820833,
#     'silhouette': 0.791245078628669}, 11: {'completeness': 0.75072215289063837,
#     'silhouette': 0.71871725842523415}, 12: {'completeness': 0.74833365903720783,
#     'silhouette': 0.73131786339383287}, 13: {'completeness': 0.73554969737127163,
#     'silhouette': 0.70007530048915068}, 14: {'completeness': 0.75336229939461519,
#     'silhouette': 0.67939835614242239}, 15: {'completeness': 0.76546459569660819,
#     'silhouette': 0.6386106078687761}}},
#  {('palestrina',
#    'major',
#    1): {2: {'completeness': 0.72132134325115549,
#     'silhouette': 0.7147470728195634}, 3: {'completeness': 0.73579357755820918,
#     'silhouette': 0.61290956919334971}, 4: {'completeness': 0.68478700723348762,
#     'silhouette': 0.62718763040586045}, 5: {'completeness': 0.71596895685075723,
#     'silhouette': 0.64097419153769308}, 6: {'completeness': 0.68183474817389067,
#     'silhouette': 0.54111076279673487}, 7: {'completeness': 0.75233810303573656,
#     'silhouette': 0.60279607966859039}, 8: {'completeness': 0.72099007808300697,
#     'silhouette': 0.65308033161969692}, 9: {'completeness': 0.74058070589446379,
#     'silhouette': 0.67902891785461261}, 10: {'completeness': 0.73267346293079549,
#     'silhouette': 0.73008684961293124}, 11: {'completeness': 0.70852597798293115,
#     'silhouette': 0.6737391603797438}, 12: {'completeness': 0.75017552498335438,
#     'silhouette': 0.72346512146102016}, 13: {'completeness': 0.76248966490060022,
#     'silhouette': 0.68681621864926146}, 14: {'completeness': 0.76826410419979463,
#     'silhouette': 0.64070359812427402}, 15: {'completeness': 0.78968655761582329,
#     'silhouette': 0.64660431572709109}}},
#  {('palestrina',
#    'major',
#    2): {2: {'completeness': 0.66856799762217256,
#     'silhouette': 0.70137393485757527}, 3: {'completeness': 0.62613859482854617,
#     'silhouette': 0.52032313165489141}, 4: {'completeness': 0.6899591185005437,
#     'silhouette': 0.63397661313125098}, 5: {'completeness': 0.70125116463555603,
#     'silhouette': 0.62113435546403184}, 6: {'completeness': 0.71529810284008677,
#     'silhouette': 0.62805653480713419}, 7: {'completeness': 0.72951710691517602,
#     'silhouette': 0.61846968669422919}, 8: {'completeness': 0.75318659045043301,
#     'silhouette': 0.65408531518412816}, 9: {'completeness': 0.71270625838267732,
#     'silhouette': 0.63513350466217044}, 10: {'completeness': 0.71577977254307967,
#     'silhouette': 0.65521056118671228}, 11: {'completeness': 0.70489507242299554,
#     'silhouette': 0.7054893954948277}, 12: {'completeness': 0.74134150140479116,
#     'silhouette': 0.69740897143512981}, 13: {'completeness': 0.75448900650977835,
#     'silhouette': 0.65358157392884708}, 14: {'completeness': 0.44005960641102176,
#     'silhouette': 0.77471815097786378}, 15: {'completeness': 0.76275890573806548,
#     'silhouette': 0.63666192016240153}}},
#  {('palestrina',
#    'major',
#    3): {2: {'completeness': 0.7389728034182601,
#     'silhouette': 0.73609256395418321}, 3: {'completeness': 0.78738168034522149,
#     'silhouette': 0.54113885566358133}, 4: {'completeness': 0.6505929962184176,
#     'silhouette': 0.62326293617246298}, 5: {'completeness': 0.71796465098506668,
#     'silhouette': 0.64330097936410302}, 6: {'completeness': 0.73827876356038769,
#     'silhouette': 0.63187136436303493}, 7: {'completeness': 0.69021222257606618,
#     'silhouette': 0.55114135204830716}, 8: {'completeness': 0.70607130858748701,
#     'silhouette': 0.5915604841972345}, 9: {'completeness': 0.7289903746600005,
#     'silhouette': 0.64423160392677969}, 10: {'completeness': 0.69423439824754096,
#     'silhouette': 0.64838326082525521}, 11: {'completeness': 0.74191034187290239,
#     'silhouette': 0.73100506626726303}, 12: {'completeness': 0.75221850855250449,
#     'silhouette': 0.7149540083965229}, 13: {'completeness': 0.7639634063917754,
#     'silhouette': 0.72261449384544518}, 14: {'completeness': 0.76070847062782876,
#     'silhouette': 0.65858778993505662}, 15: {'completeness': 0.76448186451802813,
#     'silhouette': 0.63792889952646381}}},
#  {('palestrina',
#    'major',
#    4): {2: {'completeness': 0.66920406703217872,
#     'silhouette': 0.72404908980051785}, 3: {'completeness': 0.76904338480736156,
#     'silhouette': 0.63871299461071718}, 4: {'completeness': 0.69111676540290423,
#     'silhouette': 0.59017191086676091}, 5: {'completeness': 0.72684621021964224,
#     'silhouette': 0.63794213539778932}, 6: {'completeness': 0.72973572774100592,
#     'silhouette': 0.56119994644014037}, 7: {'completeness': 0.73676120894826702,
#     'silhouette': 0.57639084349617076}, 8: {'completeness': 0.39726880218847466,
#     'silhouette': 0.80912148361186143}, 9: {'completeness': 0.71281233656713794,
#     'silhouette': 0.64950261706886514}, 10: {'completeness': 0.69821811569779202,
#     'silhouette': 0.69127683292129027}, 11: {'completeness': 0.72561999161816881,
#     'silhouette': 0.73974317391169819}, 12: {'completeness': 0.77291359090319489,
#     'silhouette': 0.71377148028349779}, 13: {'completeness': 0.74699454428733192,
#     'silhouette': 0.68797548167057665}, 14: {'completeness': 0.79488748547600119,
#     'silhouette': 0.70637589560090586}, 15: {'completeness': 0.77315418302510786,
#     'silhouette': 0.65390851610338652}}},
#  {('palestrina',
#    'minor',
#    0): {2: {'completeness': 0.45128172593811189,
#     'silhouette': 0.68881658212199282}, 3: {'completeness': 0.55321589633628121,
#     'silhouette': 0.57523012941798735}, 4: {'completeness': 0.75571806052241408,
#     'silhouette': 0.82398640913641363}, 5: {'completeness': 0.57116404234172991,
#     'silhouette': 0.69152030866835201}, 6: {'completeness': 0.58086195199293,
#     'silhouette': 0.61400620761418889}, 7: {'completeness': 0.63399391256722937,
#     'silhouette': 0.6657695035369634}, 8: {'completeness': 0.73374803480294559,
#     'silhouette': 0.57647626629056703}, 9: {'completeness': 0.71213548766482127,
#     'silhouette': 0.62614398877021793}, 10: {'completeness': 0.494161946482713,
#     'silhouette': 0.73779681142019637}, 11: {'completeness': 0.72462295079728967,
#     'silhouette': 0.568980747006404}, 12: {'completeness': 0.70057739918643969,
#     'silhouette': 0.52819841944873847}, 13: {'completeness': 0.74292268598653344,
#     'silhouette': 0.58097582354274646}, 14: {'completeness': 0.78388802067498187,
#     'silhouette': 0.62255166319318345}, 15: {'completeness': 0.79798600127211061,
#     'silhouette': 0.59166524534535569}}},
#  {('palestrina',
#    'minor',
#    1): {2: {'completeness': 0.590144027915813,
#     'silhouette': 0.6882113792179021}, 3: {'completeness': 0.6229611567363883,
#     'silhouette': 0.56974385997884835}, 4: {'completeness': 0.62472278183110941,
#     'silhouette': 0.79810712735786171}, 5: {'completeness': 0.50560838831101529,
#     'silhouette': 0.6861462958464839}, 6: {'completeness': 0.60511433294705308,
#     'silhouette': 0.60125395511933366}, 7: {'completeness': 0.57414438566440673,
#     'silhouette': 0.55716190831712598}, 8: {'completeness': 0.67241149792615262,
#     'silhouette': 0.61261425749580112}, 9: {'completeness': 0.78618852952013851,
#     'silhouette': 0.59088611177780159}, 10: {'completeness': 0.67824259472749404,
#     'silhouette': 0.5680553756351574}, 11: {'completeness': 0.77971920181184939,
#     'silhouette': 0.62681410564818463}, 12: {'completeness': 0.75162691106855206,
#     'silhouette': 0.55250407403270763}, 13: {'completeness': 0.72550585134405809,
#     'silhouette': 0.58861793888938052}, 14: {'completeness': 0.72511817955099178,
#     'silhouette': 0.56134411208714252}, 15: {'completeness': 0.82150973327952836,
#     'silhouette': 0.58692908348804917}}},
#  {('palestrina',
#    'minor',
#    2): {2: {'completeness': 0.45815230122696504,
#     'silhouette': 0.65968241689280571}, 3: {'completeness': 0.56510783042114499,
#     'silhouette': 0.63530811190521674}, 4: {'completeness': 0.64328612428931498,
#     'silhouette': 0.79970653718637275}, 5: {'completeness': 0.55219253640361399,
#     'silhouette': 0.68973702542790793}, 6: {'completeness': 0.57462263754817999,
#     'silhouette': 0.53439164634893366}, 7: {'completeness': 0.68046663324555112,
#     'silhouette': 0.64575515665885719}, 8: {'completeness': 0.62229515996042306,
#     'silhouette': 0.51428899944577944}, 9: {'completeness': 0.72499978093462347,
#     'silhouette': 0.51053044311143903}, 10: {'completeness': 0.746385875672126,
#     'silhouette': 0.6098191381967667}, 11: {'completeness': 0.72551157740351113,
#     'silhouette': 0.5783091995695292}, 12: {'completeness': 0.78672659191365346,
#     'silhouette': 0.597965592486143}, 13: {'completeness': 0.75701486980430277,
#     'silhouette': 0.52627544215624289}, 14: {'completeness': 0.76433478872288974,
#     'silhouette': 0.64254088572946833}, 15: {'completeness': 0.60917800592743221,
#     'silhouette': 0.61113838398660425}}},
#  {('palestrina',
#    'minor',
#    3): {2: {'completeness': 0.51994936805273573,
#     'silhouette': 0.67288635792049856}, 3: {'completeness': 0.20930123786979557,
#     'silhouette': 0.83779644660408292}, 4: {'completeness': 0.73905351639725281,
#     'silhouette': 0.80121829281042123}, 5: {'completeness': 0.26699137340168,
#     'silhouette': 0.8155229791563291}, 6: {'completeness': 0.82060517362903052,
#     'silhouette': 0.72907011696417079}, 7: {'completeness': 0.64277644412336121,
#     'silhouette': 0.60008038420076137}, 8: {'completeness': 0.63529252395955627,
#     'silhouette': 0.59094832210687465}, 9: {'completeness': 0.70054369520632775,
#     'silhouette': 0.57294506658931199}, 10: {'completeness': 0.71562888924133528,
#     'silhouette': 0.49019634380685811}, 11: {'completeness': 0.78926370607970753,
#     'silhouette': 0.61557223364022395}, 12: {'completeness': 0.71201800388195924,
#     'silhouette': 0.54770929491887155}, 13: {'completeness': 0.74933030269738432,
#     'silhouette': 0.58792894243417071}, 14: {'completeness': 0.47556292726654065,
#     'silhouette': 0.79064017396408381}, 15: {'completeness': 0.75322165744998615,
#     'silhouette': 0.57048477977484235}}},
#  {('palestrina',
#    'minor',
#    4): {2: {'completeness': 0.69392527189294251,
#     'silhouette': 0.6268961070389365}, 3: {'completeness': 0.55067788093968972,
#     'silhouette': 0.62605798973372606}, 4: {'completeness': 0.62997797089505958,
#     'silhouette': 0.80659242156215405}, 5: {'completeness': 0.55730641470626507,
#     'silhouette': 0.69109666253693236}, 6: {'completeness': 0.59820714151812293,
#     'silhouette': 0.68113744074516935}, 7: {'completeness': 0.63972387585095714,
#     'silhouette': 0.55024193680402866}, 8: {'completeness': 0.682751981486037,
#     'silhouette': 0.55421939759312711}, 9: {'completeness': 0.74172213621920424,
#     'silhouette': 0.57257258633009289}, 10: {'completeness': 0.71336296117620079,
#     'silhouette': 0.57830961157607863}, 11: {'completeness': 0.77664126450870219,
#     'silhouette': 0.62633394141607923}, 12: {'completeness': 0.74728416168743017,
#     'silhouette': 0.60809077629137065}, 13: {'completeness': 0.76198036512401024,
#     'silhouette': 0.55414001338606345}, 14: {'completeness': 0.75873494663607277,
#     'silhouette': 0.61227685621665939}, 15: {'completeness': 0.77730754997708307,
#     'silhouette': 0.57965359262273142}}}]

# %%
import matplotlib.pyplot as plt

# %%
alf_maj = []
alf_min = []
bach_maj = []
bach_min = []
pal_maj = []
pal_min = []
for x in j:
    for label in x.keys():
#         print(label[2])
        if label[0] == 'alfabeto_continuo':
            if label[1] == 'major':
                alf_maj.append(x)
            elif label[1] == 'minor':
                alf_min.append(x)

        elif label[0] == 'bach':
            if label[1] == 'major':
                bach_maj.append(x)
            elif label[1] == 'minor':
                bach_min.append(x)

        elif label[0] == 'palestrina':
            if label[1] == 'major':
                pal_maj.append(x)
            elif label[1] == 'minor':
                pal_min.append(x)

# %%
alf_data_maj = per_number(alf_maj)
alf_data_min = per_number(alf_min)
bach_data_maj = per_number(bach_maj)
bach_data_min = per_number(bach_min)
pal_data_maj = per_number(pal_maj)
pal_data_min = per_number(pal_min)

def per_number(variable):
    jj = []
    for num in range(2, 16):
        num_list = []
        for x in variable:
            for a in x.values():
#                 print(a)
                for i, p in a.items():
#                     print(i, num)
                    if i == num:
#                         print(i, p['silhouette'])
                        num_list.append(p['silhouette'])
            if len(num_list) > 0:
                jj.append(num_list)
#                 jj.append(all_i)
    return jj

# %%
plt.plot([np.mean(x) for x in alf_data_maj])

# %%
plt.show()

# %%
alf_maj
# Out:
# [{('alfabeto_continuo',
#    'major',
#    0): {2: {'completeness': 0.83544563202798272,
#     'silhouette': 0.96949812934582758}, 3: {'completeness': 0.83600349226648563,
#     'silhouette': 0.98173518931147485}, 4: {'completeness': 0.84891316640904324,
#     'silhouette': 0.9054803449345209}, 5: {'completeness': 0.7468733035325118,
#     'silhouette': 0.71086716309217024}, 6: {'completeness': 0.83521020007495561,
#     'silhouette': 0.64848350668140686}, 7: {'completeness': 0.7059715894053098,
#     'silhouette': 0.60426052216769377}, 8: {'completeness': 0.86618678687831752,
#     'silhouette': 0.66081271079640858}, 9: {'completeness': 0.90853037032212647,
#     'silhouette': 0.73493594782065774}, 10: {'completeness': 0.92371516950301358,
#     'silhouette': 0.78068628062951984}, 11: {'completeness': 0.91393387522635927,
#     'silhouette': 0.77755966098620555}, 12: {'completeness': 0.87476768298213248,
#     'silhouette': 0.77269527397872606}, 13: {'completeness': 0.7218262968312541,
#     'silhouette': 0.63488344257589957}, 14: {'completeness': 0.84430850553186554,
#     'silhouette': 0.76013184039323722}, 15: {'completeness': 0.83143700043795388,
#     'silhouette': 0.76507455449246675}}},
#  {('alfabeto_continuo',
#    'major',
#    1): {2: {'completeness': 0.88941694770359858,
#     'silhouette': 0.90273781070956771}, 3: {'completeness': 0.83685916533443727,
#     'silhouette': 0.98868896946185858}, 4: {'completeness': 0.84911067829702058,
#     'silhouette': 0.91474027676348879}, 5: {'completeness': 0.76715450157036924,
#     'silhouette': 0.69859320658833157}, 6: {'completeness': 0.83017463614251086,
#     'silhouette': 0.64335944877678541}, 7: {'completeness': 0.72856556451462851,
#     'silhouette': 0.5690500405744493}, 8: {'completeness': 0.87350388180841676,
#     'silhouette': 0.67454543969905523}, 9: {'completeness': 0.90661366265896559,
#     'silhouette': 0.74126730687317144}, 10: {'completeness': 0.91910441717654112,
#     'silhouette': 0.76775523431850856}, 11: {'completeness': 0.76757394170480142,
#     'silhouette': 0.69961665336682344}, 12: {'completeness': 0.77468808399646816,
#     'silhouette': 0.6639607645801372}, 13: {'completeness': 0.86522503477222346,
#     'silhouette': 0.76682961058809807}, 14: {'completeness': 0.8465128715776522,
#     'silhouette': 0.75533994157550211}, 15: {'completeness': 0.82450639487248345,
#     'silhouette': 0.7482071712386934}}},
#  {('alfabeto_continuo',
#    'major',
#    2): {2: {'completeness': 0.85230465237316544,
#     'silhouette': 0.92200197395463268}, 3: {'completeness': 0.65415629764516647,
#     'silhouette': 0.86071216647441506}, 4: {'completeness': 0.82587720797187036,
#     'silhouette': 0.87780016433864527}, 5: {'completeness': 0.76334166969845663,
#     'silhouette': 0.72154046177739661}, 6: {'completeness': 0.79001431399602162,
#     'silhouette': 0.61278267638342698}, 7: {'completeness': 0.75024072323973157,
#     'silhouette': 0.63705755106233686}, 8: {'completeness': 0.90456649587770099,
#     'silhouette': 0.68519401458949425}, 9: {'completeness': 0.91391519840690782,
#     'silhouette': 0.74142255825119252}, 10: {'completeness': 0.93186598714990898,
#     'silhouette': 0.82205193886281591}, 11: {'completeness': 0.90435240292641728,
#     'silhouette': 0.79483310957403286}, 12: {'completeness': 0.85512542569327998,
#     'silhouette': 0.75712636329895544}, 13: {'completeness': 0.88637580068424782,
#     'silhouette': 0.77288560117857674}, 14: {'completeness': 0.84341181623850847,
#     'silhouette': 0.7631383208347543}, 15: {'completeness': 0.83079570923642176,
#     'silhouette': 0.75709544882648383}}},
#  {('alfabeto_continuo',
#    'major',
#    3): {2: {'completeness': 0.89337813889365569,
#     'silhouette': 0.89687225841356732}, 3: {'completeness': 0.85201974219889898,
#     'silhouette': 0.98250543792356215}, 4: {'completeness': 0.85600937593824522,
#     'silhouette': 0.89887975063402159}, 5: {'completeness': 0.77604003776017172,
#     'silhouette': 0.70601252716338148}, 6: {'completeness': 0.78057110281578224,
#     'silhouette': 0.62456993230880831}, 7: {'completeness': 0.87437939825204658,
#     'silhouette': 0.60731479242863584}, 8: {'completeness': 0.87722643589577987,
#     'silhouette': 0.67710659970867448}, 9: {'completeness': 0.91883934739976636,
#     'silhouette': 0.72449025342155093}, 10: {'completeness': 0.92535041863411216,
#     'silhouette': 0.78008106841068736}, 11: {'completeness': 0.90867403608427566,
#     'silhouette': 0.78395060761022139}, 12: {'completeness': 0.87438818308381339,
#     'silhouette': 0.75739158819860442}, 13: {'completeness': 0.838652929905497,
#     'silhouette': 0.72209796699120399}, 14: {'completeness': 0.85442740669447836,
#     'silhouette': 0.74262392205147654}, 15: {'completeness': 0.82653867912550416,
#     'silhouette': 0.76547953343524233}}},
#  {('alfabeto_continuo',
#    'major',
#    4): {2: {'completeness': 0.91108135467880003,
#     'silhouette': 0.88115978147161}, 3: {'completeness': 0.85501132168910976,
#     'silhouette': 0.9868927959474918}, 4: {'completeness': 0.85707491576666117,
#     'silhouette': 0.91702826619265654}, 5: {'completeness': 0.76816767042480849,
#     'silhouette': 0.69545755641762519}, 6: {'completeness': 0.81670980678449823,
#     'silhouette': 0.64159994743138837}, 7: {'completeness': 0.83573731630394699,
#     'silhouette': 0.57945206693250972}, 8: {'completeness': 0.716157018707967,
#     'silhouette': 0.6128940020293544}, 9: {'completeness': 0.89946812156764377,
#     'silhouette': 0.72130575378377448}, 10: {'completeness': 0.78442619377211875,
#     'silhouette': 0.68031761224025866}, 11: {'completeness': 0.91187396248261288,
#     'silhouette': 0.77834599197915588}, 12: {'completeness': 0.90672158330802066,
#     'silhouette': 0.78211382846924959}, 13: {'completeness': 0.76721086813237382,
#     'silhouette': 0.67319384657743431}, 14: {'completeness': 0.84527438172557168,
#     'silhouette': 0.76797037448430794}, 15: {'completeness': 0.82114966279342561,
#     'silhouette': 0.7762925097850073}}}]

# %%
np.mean(jj)
# Out:
# 0.64882730752797235
