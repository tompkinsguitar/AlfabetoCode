# %%
from Continuo import kmeans_inversion as ki

# %%
ki.silhouette_analysis(ki.k_means_data(ki.A, 2, ki.B))
# Out:
# n_digits: 2, 	 n_samples 419, 	 n_features 72
# _______________________________________________________________________________
# init        time     inertia  homo     compl   v-meas  ARI  AMI   silhouette
# k-means++   0.15s    125606   0.114   1.000   0.205   0.000   -0.000    0.350
#    random   0.08s    125606   0.114   1.000   0.205   0.000   -0.000    0.350
# PCA-based   0.01s    125606   0.114   1.000   0.205   0.000   -0.000    0.350
# _______________________________________________________________________________
# For n_clusters = 2 The average silhouette_score is : 0.652595194139
# For n_clusters = 3 The average silhouette_score is : 0.518242477977
# For n_clusters = 4 The average silhouette_score is : 0.400014898524
# For n_clusters = 5 The average silhouette_score is : 0.380195240625
# For n_clusters = 6 The average silhouette_score is : 0.381961158811
# For n_clusters = 7 The average silhouette_score is : 0.377184648833
# ...
